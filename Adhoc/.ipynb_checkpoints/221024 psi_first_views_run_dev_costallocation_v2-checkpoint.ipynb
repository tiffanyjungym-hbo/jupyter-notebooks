# %%
import os
import sys

import pandas as pd
import numpy as np
import pickle
from datetime import date, datetime, timedelta

from category_encoders import OneHotEncoder
import xgboost as xgb

import boto3
import logging 

logger = logging.getLogger()
logging.basicConfig(level=logging.INFO)
logger.info(f'Starting Notebook')
# Out:
# INFO:root:Starting Notebook

# %%
from io import StringIO
class Utils():
    @staticmethod
    def to_csv_s3(content, bucket, key_path, filename):
        client = boto3.client('s3')
        key = os.path.join(key_path, filename)
        csv_buffer = StringIO()
        content.to_csv(csv_buffer)
        client.put_object(Bucket=bucket, Key=key, Body=csv_buffer.getvalue(), ACL="bucket-owner-full-control")
        logger.info(f'Saved to {bucket}/{key}')
    
    @staticmethod
    def to_pkl_s3(content, bucket, key_path, filename):
        client = boto3.client('s3')
        key = os.path.join(key_path, filename)
        obj = pickle.dumps(content)
        client.put_object(Bucket=bucket, Key=key, Body=obj)
        logger.info(f'Saved model to {os.path.join(bucket, key)}')
        logger.info(f'Saved to {bucket}/{key}')

    @staticmethod
    def read_csv_s3(bucket, key_path,filename):
        client = boto3.client('s3')
        key = os.path.join(key_path, filename)
        logger.info(f'Reading from {bucket}/{key}')
        obj = client.get_object(Bucket=bucket, Key=key)
        df = pd.read_csv(obj['Body'], na_values="\\N")
        return df
        
    @staticmethod
    def read_pkl_s3(bucket, key_path,filename):
        client = boto3.client('s3')
        key = os.path.join(key_path, filename)
        logger.info(f'Reading from {bucket}/{key}')
        obj = client.get_object(Bucket=bucket, Key=key)
        body = obj['Body'].read()
        model = pickle.loads(body)
        return model


class BaseFeatureMunger():
    def __init__(self, df_in, df_imdb_munged, df_talent, mode, date_run):
        self.df_in = df_in
        self.df_imdb_munged = df_imdb_munged
        self.df_talent = df_talent
        self.mode = mode
        self.date_run = date_run
        self.clean_df()
        self.fill_missing_data()
        if mode=='train':
            self.filter_df()
        self.get_datetime_features()
        self.aggregate_df()
        self.munge_talent_feature()
        self.merge_features()
        self.get_first_views()
        self.return_df()
        
    def return_df(self):
        col_base = ['title_id', 'title_name', 'season_number',
       'content_category', 'content_source', 'category',
       'tier', 'effective_start_date', 'request_date', 'first_views',
       'days_since_premiere', 'days_on_platform', 'start_year']
        
        col_title = ['title_name', 'title_id','season_number','tier','content_category','category',
                'effective_start_date', 'schedule_label', 'prequel_count', 'prequel_featured_count','page_views','first_views','first_views_log']
        if self.mode=='train':
            return self.df_in[col_base], self.df_in_title[col_title]
        elif self.mode=='predict':
            return self.df_in_title[col_title]

    def clean_df(self):
        logger.info(f'base_data shape: {self.df_in.shape}')
        logger.info(f'base_data null: {self.df_in.isnull().sum()}')
        self.df_in.columns= self.df_in.columns.str.lower()
        self.dic_dtype = {'season_number':int, 'tier':int}
        self.df_in = self.df_in.astype(self.dic_dtype)
        self.df_in['effective_start_date'] = pd.to_datetime(self.df_in['effective_start_date'])
        
    def fill_missing_data(self):
        self.df_in['content_category'] = self.df_in['content_category'].fillna('series')
        self.df_in.loc[self.df_in['category'].isin(['Specials']), 'content_category']='special'
        self.df_in.loc[self.df_in['category'].isin(['Popcorn','Pay 1 WB Theatricals','Scripted Features', 'Pay1']), 'content_category']='movies'
        self.df_in.loc[self.df_in['title_name'].str.contains('Harry Potter'), 'content_category']='special'
        self.df_in = self.df_in.fillna(0)

    def filter_df(self):
        self.date_max = datetime.strptime(self.date_run, '%Y-%m-%d')- timedelta(days=60)
        self.date_min='2021-01-01'
        self.df_in = self.df_in[(self.df_in['effective_start_date']<=self.date_max)]
#         self.df_in = self.df_in[(self.df_in['effective_start_date']>=self.date_min)]

    def get_datetime_features(self):
        self.df_in['start_year'] = self.df_in['effective_start_date'].dt.year
        self.df_in['start_quarter'] = self.df_in['effective_start_date'].dt.quarter
        
    def aggregate_df(self):
        grpby_title= ['title_name', 'title_id','tier','content_category','category','season_number',
                'effective_start_date', 'schedule_label']
        self.df_in_title = self.df_in[grpby_title + ['first_views']].groupby(by=grpby_title).sum().reset_index()
    
    def munge_talent_feature(self):
        grpby = ['title_name', 'season_number', 'category', 'tier', 'effective_start_date'] 
        self.df_talent.columns= self.df_talent.columns.str.lower()
        self.df_talent = self.df_talent.fillna(0)
        self.df_talent['effective_start_date'] = pd.to_datetime(self.df_talent['effective_start_date']).dt.date
        self.df_talent['effective_start_date'] = pd.to_datetime(self.df_talent['effective_start_date'])
        self.df_talent['tier'] = self.df_talent['tier'].astype(int)
        
        self.df_pv_title = self.df_talent[self.df_talent.talent_category=='cast']
        self.df_pv_title = self.df_pv_title.sort_values(by=grpby+['page_views'], ascending=False)
        self.df_pv_title = self.df_pv_title.groupby(by=grpby).head(3).reset_index(drop=True).groupby(by=grpby).sum().reset_index()

    def merge_features(self):
        key_merge = ['title_name','season_number', 'category', 'tier', 'effective_start_date']
        self.df_in_title = self.df_in_title.merge(self.df_imdb_munged, on= key_merge+['content_category'], how='left')\
                                        .merge(self.df_pv_title, on=key_merge, how='left')
        logger.info(f'title imdb shape: {self.df_in_title.shape}')
#         logger.info(f'title imdb features null: {self.df_in_title.isnull().sum()}')
        self.df_in_title = self.df_in_title.fillna(0)
        
    def get_first_views(self):
        ## Scale first_views 
        self.df_in_title['first_views_log'] = np.log(self.df_in_title['first_views']) 
        self.df_in_title.loc[(self.df_in_title.first_views==0), 'first_views_log']=0
        

class IMDBFeatureMunger(BaseFeatureMunger):
    
    def __init__(self, df_in, mode, date_run):
        self.df_in = df_in
        self.date_run = date_run 
        
        self.clean_df()
        if mode=='train':
            self.filter_df()
        self.get_series_features()
#         if mode=='train':
#             self.adjust_series_for_training_data()
        self.get_non_series_prequel_features()
        self.get_non_series_prequel_ref_features()
        self.merge_non_series_features()
        self.return_df()
        
    def return_df(self):
        col_imdb = ['title_name', 'season_number', 'content_category', 'category', 
                    'tier', 'effective_start_date', 'prequel_count', 'prequel_featured_count']
        self.df_imdb_munged = pd.concat([self.df_series_title, self.df_nseries_title])
#         self.df_imdb_munged = self.df_nseries_title.copy()
        self.df_imdb_munged = self.df_imdb_munged[col_imdb].groupby(by=col_imdb[:-2]).sum().reset_index()
        return self.df_imdb_munged
    
    def get_series_features(self):
        grpby_series = ['title_name','season_number','content_category','category','tier','effective_start_date']
        self.df_series = self.df_in[(self.df_in.content_category.isin(['series'])) & (self.df_in.reference_type.isin(['featured_in']))] 
        self.df_series_title = self.df_series.groupby(by=grpby_series).agg({'reference_title_id':'nunique'}).reset_index()
        self.df_series_title = self.df_series_title.rename(columns={'reference_title_id':'ref_ref_featured_in'})
        self.df_series_title['prequel_count'] = self.df_series_title['season_number']-1
        self.df_series_title['prequel_featured_count'] = self.df_series_title['ref_ref_featured_in']

    def adjust_series_for_training_data(self):     
        self.df_series_title['ref_ref_featured_in'] = (self.df_series_title['ref_ref_featured_in'] * (self.df_series_title['season_number']-1))/self.df_series_title['season_number']
        self.df_series_title.loc[self.df_series_title.season_number>1, 'prequel_featured_count'] = (self.df_series_title['ref_ref_featured_in'])/(self.df_series_title['season_number']-1)     
        
        
    def get_non_series_prequel_features(self):
        self.grpby_nseries=['title_name','season_number','content_category','category','tier','effective_start_date','imdb_imdb_series_id']
        self.df_nseries = self.df_in[(self.df_in.reference_type.isin(['follows','spin_off_from','remake_of','version_of'])) & ((self.df_in.reference_title_type.isin(['movie','tvSeries', 'videoGame'])))] 
        self.df_nseries['ref_ref_count'] = self.df_nseries.groupby('reference_title_id').reference_reference_title_id.transform('nunique')
        self.df_nseries = self.df_nseries[self.df_nseries['ref_ref_count']>0] ## Only count references that have secondary references 
        
        self.df_nseries_preq = self.df_nseries.groupby(by=self.grpby_nseries+['reference_type']).agg({'reference_title_id':'nunique'}).reset_index()
        self.df_nseries_preq = pd.pivot_table(self.df_nseries_preq, 
                          index = self.grpby_nseries, 
                          columns = 'reference_type', 
                          values = 'reference_title_id').reset_index()
        self.df_nseries_preq = self.df_nseries_preq.rename(columns={'follows':'ref_follows',  
                                                                          'spin_off_from':'ref_spin_off_from', 
                                                                          'remake_of':'ref_remake_of',
                                                                          'version_of':'ref_version_of'})
    def get_non_series_prequel_ref_features(self):
        self.df_nseries_preq_ref = self.df_nseries.groupby(by=self.grpby_nseries+['reference_reference_type']).agg({'reference_reference_title_id':'nunique'}).reset_index()
#         display(self.df_nseries_preq_ref[self.df_nseries_preq_ref.title_name=='The Matrix Resurrections'])
        self.df_nseries_preq_ref = pd.pivot_table(self.df_nseries_preq_ref, 
                  index = self.grpby_nseries, 
                  columns = 'reference_reference_type', 
                  values = 'reference_reference_title_id').reset_index()        
        self.df_nseries_preq_ref = self.df_nseries_preq_ref.rename(columns={'featured_in':'ref_ref_featured_in'})
        
    def merge_non_series_features(self):
        col_preq = ['title_name', 'tier','season_number','content_category','category','effective_start_date','imdb_imdb_series_id','ref_follows','ref_spin_off_from','ref_remake_of', 'ref_version_of']
        col_ref_ref = ['title_name','season_number','category','ref_ref_featured_in']
        self.df_nseries_title = self.df_nseries_preq[col_preq].merge(self.df_nseries_preq_ref[col_ref_ref], how='outer', on=['title_name','season_number','category'])
        self.df_nseries_title['prequel_count'] = self.df_nseries_title[['ref_follows','ref_spin_off_from','ref_remake_of','ref_version_of']].sum(axis=1)
        self.df_nseries_title['prequel_featured_count'] = self.df_nseries_title['ref_ref_featured_in']/self.df_nseries_title['prequel_count']

        
        
class PreProcessor():
    def __init__(self, df_in, mode, date_run):
        self.df_in = df_in
        self.date_run = date_run
        self.get_parameters()
        self.adjust_tiers()
        self.get_series_nonseries_feature()
        self.categorize_talent_feature()
        self.winsorize_feature()
        if mode=='train':
            self.winsorize_label()
            self.resample_data()
        self.return_df()
        
    def return_df(self):
        return self.df_in
    
    def get_parameters(self):
        self.max_firstviews = 1000000
        self.old_sampling_rate = 0.4
        self.recent_sampling_rate = 0.6
        self.pay1_sampling_rate = 0.5
        
    def adjust_tiers(self):
        self.df_in['tier_adj'] = self.df_in['tier']
        self.df_in.loc[(self.df_in.title_name=='Reminiscence'), 'tier_adj'] = 2
        self.df_in.loc[(self.df_in.category=='Pay1') & (self.df_in.tier==1), 'tier_adj'] = 2
        self.df_in.loc[(self.df_in.category=='Pay1') & (self.df_in.tier==2), 'tier_adj'] = 3
        self.df_in.loc[(self.df_in.effective_start_date < '2022-04-01') & (self.df_in.category=='Popcorn') & (self.df_in.tier==1), 'tier_adj'] = 0
        self.df_in.loc[self.df_in.title_name=='Avatar 2', 'tier_adj'] = 1
        
    def get_series_nonseries_feature(self):
        self.df_in['prequel_count_s'] = self.df_in['prequel_count']
        self.df_in['prequel_featured_count_s'] = self.df_in['prequel_featured_count']
        self.df_in['page_views_s'] = self.df_in['page_views']
        
        self.df_in.loc[(self.df_in.content_category!='movies'),['page_views','prequel_count','prequel_featured_count']] = -1
        self.df_in.loc[(self.df_in.content_category=='movies'), ['page_views_s','prequel_count_s','prequel_featured_count_s']] = -1
        self.df_in.loc[(self.df_in.category=='Kids & Family'), ['page_views_s','prequel_count_s','prequel_featured_count_s']] = 0
        
        for i in ['prequel_featured_count','prequel_featured_count_s', 'page_views_s','page_views']:
            self.df_in.loc[(self.df_in.tier==3), i] = 0
            self.df_in.loc[(self.df_in.tier==2), i] = self.df_in[i]*0.5
    
#         self.df_in.loc[(self.df_in.tier_adj>=2), ['page_views','prequel_featured_count','page_views_s','prequel_featured_count_s']] = -2
        
    def categorize_talent_feature(self):
#         page_views_bin = [-10, -2, -1, 100000, 100000000]  # -1: series, -2: low tier, 
#         page_views_s_bin = [-10, -2, -1, 100000, 100000000]  # -1: movie, -2: low tier, 
#         page_views_label = [-2, -1, 1000, 100000]
#         page_views_s_label = [-2, -1, 100000, 200000]
        page_views_bin = [-1, 1, 10000, 100000000]  # -1: series, -2: low tier, 
        page_views_label = ['NA', 'Low', 'High']
        
        self.df_in['page_views']= pd.cut(self.df_in['page_views'], bins=page_views_bin,labels=page_views_label).fillna('NA').astype(str)
        self.df_in['page_views_s']= pd.cut(self.df_in['page_views_s'], bins=page_views_bin,labels=page_views_label).fillna('NA').astype(str)
        
        prequel_featured_count_bin = [-1, 0, 10, 30, 1000]  # -1: series, -2: low tier, 
        prequel_featured_count_label = ['NA', 'Low', 'Med', 'High']
        
        self.df_in['prequel_featured_count']= pd.cut(self.df_in['prequel_featured_count'], bins=prequel_featured_count_bin,labels=prequel_featured_count_label).fillna('NA').astype(str)
        self.df_in['prequel_featured_count_s']= pd.cut(self.df_in['prequel_featured_count_s'], bins=prequel_featured_count_bin,labels=prequel_featured_count_label).fillna('NA').astype(str)

    def winsorize_feature(self):
        ## IMDB Features
        self.df_in.loc[(self.df_in['prequel_count']>5), ['prequel_count']] = 5
        self.df_in.loc[(self.df_in['prequel_count_s']>5), ['prequel_count_s']] = 5
#         self.df_in.loc[(self.df_in['prequel_featured_count']>40), ['prequel_featured_count']] = 40   
#         self.df_in.loc[self.df_in['prequel_featured_count_s']>40, 'prequel_featured_count_s'] = 40

    def winsorize_label(self):
        self.df_in.loc[self.df_in.first_views>self.max_firstviews, 'first_views'] = self.max_firstviews
    
    def resample_data(self):  
        self.df_in_old = self.df_in[(self.df_in.effective_start_date < datetime.strptime(self.date_run, '%Y-%m-%d')- timedelta(days=270))]
        self.df_in_recent = self.df_in[(self.df_in.effective_start_date >= datetime.strptime(self.date_run, '%Y-%m-%d')- timedelta(days=270))]
        target_count = self.df_in.groupby(by=['tier_adj','category'])['title_name'].count().max()*2
        print(target_count)
        target_count_old = int(round(target_count*self.old_sampling_rate))
        target_count_new = int(round(target_count*self.recent_sampling_rate))
        
        ## Loop through old and recent data
        df_resample_list = []
        for df_sample, target_count in zip([self.df_in_old, self.df_in_recent], [target_count_old, target_count_new]):
            list_tier_cat= df_sample[['tier_adj','category']].drop_duplicates(subset=['tier_adj','category']).values.tolist()
            
            ## Loop through unique combination of tier & category to resample 
            for tier_cat in list_tier_cat:
                if tier_cat[1]=='Pay1':
                    df_resample_list.append(df_sample[(df_sample.tier_adj==tier_cat[0]) & (df_sample.category==tier_cat[1])]\
                                        .sample(int(round(target_count*self.pay1_sampling_rate)), replace=True))                
                else:
                    df_resample_list.append(df_sample[(df_sample.tier_adj==tier_cat[0]) & (df_sample.category==tier_cat[1])]\
                                        .sample(target_count, replace=True))
        self.df_in = pd.concat(df_resample_list, axis=0)

    
    
class XGB(Utils):
    def __init__(self, df_in, mode, date_run):
        self.df_in = df_in    
        self.mode = mode
        self.date_run = date_run
        self.get_parameters()
        
        if mode=='train':
            self.train_xgb()
            self.save_model()
        elif mode=='predict':
            self.get_model()
            self.predict_xgb()
            self.return_df()
            
    @staticmethod
    def _encode(df, categoricals):
        
        """
        perform category encoding on the data
        :param df: dataframe to be encoded
        :param categoricals: list of name of categorical columns
        :return ohe, x_ohe: OHE object and OHE-encoded data
        """
        ohe = OneHotEncoder(cols=categoricals, 
                            handle_unknown='return_nan',
                           handle_missing='return_nan',  
                           use_cat_names=True) 
        x_ohe = ohe.fit_transform(df)
        return ohe, x_ohe
    
    def return_df(self):
        return self.df_pred
    
    def get_parameters(self):
        self.target = 'first_views_log'
        self.features_cat=['tier_adj','category','content_category']#, 'page_views', 'page_views_s','prequel_featured_count','prequel_featured_count_s'] 
        self.features_cont= []# 'prequel_count_s','prequel_count',] 
        self.param_xgb = {"booster":"gbtree",
                     "objective":"reg:squarederror",
                    "gamma":1}

    def train_xgb(self):
        x_train = self.df_in[self.features_cat + self.features_cont]
        y_train = self.df_in[self.target]
        self.ohe, x_ohe = self._encode(x_train, self.features_cat)
        dm_train = xgb.DMatrix(x_ohe, label=y_train)

        ## train 
        self.model = xgb.train(params = self.param_xgb, dtrain = dm_train, num_boost_round = 10)
        
    def save_model(self):
        dict_model = {'model': self.model, 'ohe': self.ohe}
        Utils.to_pkl_s3(dict_model, input_bucket, key_path, f'fv_{date_train}.pkl')
        logger.info(f'Done model training {date_train}')
    
    def get_model(self):
        dict_model = Utils.read_pkl_s3(input_bucket, key_path, f'fv_{date_train}.pkl')
        self.ohe = dict_model['ohe']
        self.model = dict_model['model']
        
    def predict_xgb(self):
        x_test = self.df_in[self.features_cat + self.features_cont]
        x_ohe_test = self.ohe.transform(x_test)
        dm_test = xgb.DMatrix(x_ohe_test)
        pred = self.model.predict(dm_test)

        self.df_pred = self.df_in[list(set(['category','content_category','tier_adj'] + self.features_cat + self.features_cont))]
        self.df_pred['first_views_log_pred'] = pred
        self.df_pred[f'first_views_pred'] = np.exp(self.df_pred[f'first_views_log_pred'])
        self.df_pred['pred_date'] = self.date_run
        self.df_pred['pred_date'] = pd.to_datetime(self.df_pred['pred_date'])
#         self.df_pred.loc[(self.df_pred.category=='Popcorn') & (self.df_pred.effective_start_date>='2022-04-01'), 'category']='Pay 1 WB Theatricals'


class FVDecay():
    def __init__(self, df_in, mode, date_run, grpby=''):
        self.df_in = df_in    
        self.mode = mode
        self.date_run = date_run
        self.grpby = grpby

        if mode=='train':
            self.get_decay_data_title()
            self.get_decay_curve()
            self.return_df()

    def return_df(self):
        return self.df_decay
        
    @staticmethod
    def apply_decay_curve(df_in, df_decay):
        category_list_train = df_decay.category.unique().tolist()
        df_in['decay_category'] = df_in['category']
        df_in.loc[(~df_in['decay_category'].isin(category_list_train)) & (df_in['decay_category']!='Popcorn'), 'decay_category'] = 'Pay1'
        
        
        ## Apply decay to prediction 
        df_pred_decay = df_in.merge(df_decay[['category','days_since_premiere','first_views_pct']], 
                                                left_on=['decay_category'], right_on=['category'], how='left', suffixes=['', '_category'])
#                             .merge(df_popcorn_decay[['category','days_since_premiere','first_views_pct']], 
#                                         on=['category','days_since_premiere'], how='left', suffixes=['', '_popcorn'])
        print(df_pred_decay.columns)
#         df_pred_decay.loc[(df_pred_decay.category=='Popcorn') & (df_pred_decay.first_views_pct.isnull()), 'first_views_pct'] = df_pred_decay['first_views_pct_popcorn']
        
        df_pred_decay[f'first_views_pred_decay'] = df_pred_decay[f'first_views_pred'] * df_pred_decay['first_views_pct']
        df_pred_decay['start_month'] = df_pred_decay['effective_start_date'].dt.to_period('M').dt.to_timestamp()
        df_pred_decay['request_date'] = df_pred_decay['effective_start_date'] + pd.to_timedelta(df_pred_decay.days_since_premiere, unit="D")
        df_pred_decay['first_view_quarter'] = df_pred_decay['request_date'].dt.to_period('Q').dt.to_timestamp()
        df_pred_decay['first_view_month'] = df_pred_decay['request_date'].dt.to_period('M').dt.to_timestamp()

        return df_pred_decay
    
    def get_decay_data_title(self):
        self.key_col = ['title_name','tier','content_category','category','season_number','effective_start_date']
        self.df_in = self.df_in[self.key_col + ['title_id','days_since_premiere','first_views']].sort_values(by=self.key_col+['days_since_premiere'])
        self.df_in['first_views_sum'] = self.df_in.groupby(self.key_col)['first_views'].transform('sum')
        self.df_in['first_views_cumsum'] = self.df_in.groupby(by=self.key_col)['first_views'].cumsum()
        self.df_in['first_views_cumpct'] = self.df_in['first_views_cumsum'] / self.df_in['first_views_sum']
        self.df_in.reset_index(inplace=True)
            
    def get_decay_curve(self):
        self.df_decay = self.df_in[[self.grpby] + ['title_id','days_since_premiere','first_views_cumpct']].sort_values(by=[self.grpby]+['days_since_premiere'])
        self.df_decay = self.df_decay.groupby(by=[self.grpby] + ['days_since_premiere']).agg({'first_views_cumpct':'median','title_id':'nunique'})
        self.df_decay = self.df_decay.rename(columns={'title_id':'title_count_training'})
        self.df_decay = self.df_decay.reset_index()
        self.df_decay['first_views_pct'] = self.df_decay.groupby(self.grpby)['first_views_cumpct'].diff()
        self.df_decay.reset_index(inplace=True)
        
        self.df_decay['days_since_premiere'] = self.df_decay['days_since_premiere'].astype(int)
        self.df_decay.loc[(self.df_decay.days_since_premiere==0),'first_views_pct'] = self.df_decay['first_views_cumpct']

# %%
dic_key_path = {'prod':'psi_first_views', 'dev':'psi_first_views', 'backtest':'psi_first_views/dev'}
dic_input_bucket = {'prod':'hbo-ingest-datascience-content', 'dev':"hbo-ingest-datascience-content-dev", 'backtest':"hbo-ingest-datascience-content-dev"}
dic_output_bucket = {'prod':'hbo-outbound-datascience-content', 'dev':"hbo-outbound-datascience-content-dev", 'backtest':"hbo-outbound-datascience-content-dev"}
# input_bucket="hbo-ingest-datascience-content-dev"
# output_bucket="hbo-outbound-datascience-content-dev"

prod_backtest = 'backtest' ## 'prod', 'backtest'
key_path = dic_key_path[prod_backtest]
input_bucket = dic_input_bucket[prod_backtest]
output_bucket = dic_output_bucket[prod_backtest]

# %%
new_tier= Utils.read_csv_s3(input_bucket, key_path, 'cost_allocation_fv_tier.csv')
new_tier.columns
new_tier = new_tier[['New Title Release Title ID', 'New Title Release Title','Season number', 'New Title Release Content Category',
       'New Title Release First Release Date', 'Combined Tier']]
new_tier = new_tier.rename(columns={'New Title Release Title ID':'title_id','New Title Release Title':'title_name','Season number':'season_number',
                                    'New Title Release Content Category':'content_category', 'New Title Release First Release Date':'effective_start_date',
                                    'Combined Tier':'tier_combined'})
new_tier
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/cost_allocation_fv_tier.csv
#                    title_id                                title_name  \
# 0     GYZWoOQ6F9cLDCAEAAABP                         Station Eleven S1
# 1     GYqM-cQPaAKeUiwEAAAAC      Pretty Little Liars: Original Sin S1
# 2     GXxis0w4EP8N_vAEAAACO                           Harley Quinn S3
# 3     GYZWoawz5wMPDwgEAAABX                     Finding Magic Mike S1
# 4     GYZLYWQj4oyfDwwEAAACi  Street Gang: How We Got To Sesame Street
# ...                     ...                                       ...
# 1481  GV22CjAE90q2QwgEAAAAI                 Todd Mcfarlane's Spawn S2
# 1482  GV22CjAE90q2QwgEAAAAI                 Todd Mcfarlane's Spawn S1
# 1483  GV1XW7AqGccPDwwEAAAAQ                        Looking: The Movie
# 1484  GV0-NiQdvBcLDRAEAAAAC      About Face: Supermodels Then And Now
# 1485  GV__phQwSYI0NlgEAAAAQ             Pete Holmes: Faces And Sounds
#
#       season_number content_category effective_start_date tier_combined
# 0                 1           series             12/16/21          Gold
# 1                 1           series              7/28/22          Gold
# 2                 3           series              7/28/22        Silver
# 3                 1           series             12/16/21        Silver
# 4                 0           movies             12/14/21        Bronze
# ...             ...              ...                  ...           ...
# 1481              2           series              5/27/20        Bronze
# 1482              1           series              5/27/20        Bronze
# 1483              0           movies              5/27/20        Bronze
# 1484              0           movies              5/27/20        Bronze
# 1485              0          special              5/27/20        Bronze
#
# [1486 rows x 6 columns]

# %%
df_in_train[df_in_train.tier_adj=='Platinum']
# Out:
#                     title_name               title_id  season_number  tier  \
# 653   Roald Dahl’s The Witches  GX5A8JQnSPQ2QFgEAAAAC              0     1
# 655   Roald Dahl’s The Witches  GX5A8JQnSPQ2QFgEAAAAC              0     1
# 657   Roald Dahl’s The Witches  GX5A8JQnSPQ2QFgEAAAAC              0     1
# 659   Roald Dahl’s The Witches  GX5A8JQnSPQ2QFgEAAAAC              0     1
# 662   Roald Dahl’s The Witches  GX5A8JQnSPQ2QFgEAAAAC              0     1
# ...                        ...                    ...            ...   ...
# 3299       House of the Dragon  GYsYeoAxKH8LCwgEAAAOR              1     0
# 3300       House of the Dragon  GYsYeoAxKH8LCwgEAAAOR              1     0
# 3301       House of the Dragon  GYsYeoAxKH8LCwgEAAAOR              1     0
# 3302       House of the Dragon  GYsYeoAxKH8LCwgEAAAOR              1     0
# 3303       House of the Dragon  GYsYeoAxKH8LCwgEAAAOR              1     0
#
#      content_category               category effective_start_date  \
# 653            movies      Scripted Features           2020-10-22
# 655            movies      Scripted Features           2020-10-22
# 657            movies      Scripted Features           2020-10-22
# 659            movies      Scripted Features           2020-10-22
# 662            movies      Scripted Features           2020-10-22
# ...               ...                    ...                  ...
# 3299           series  Scripted Drama Series           2022-08-22
# 3300           series  Scripted Drama Series           2022-08-22
# 3301           series  Scripted Drama Series           2022-08-22
# 3302           series  Scripted Drama Series           2022-08-22
# 3303           series  Scripted Drama Series           2022-08-22
#
#      schedule_label  prequel_count prequel_featured_count page_views  \
# 653            beta            0.0                     NA         NA
# 655            beta            0.0                     NA         NA
# 657            beta            0.0                     NA         NA
# 659            beta            0.0                     NA         NA
# 662            beta            0.0                     NA         NA
# ...             ...            ...                    ...        ...
# 3299           beta           -1.0                     NA         NA
# 3300           beta           -1.0                     NA         NA
# 3301           beta           -1.0                     NA         NA
# 3302           beta           -1.0                     NA         NA
# 3303           beta           -1.0                     NA         NA
#
#       first_views  first_views_log  tier_adj  prequel_count_s  \
# 653        522733        13.166826  Platinum             -1.0
# 655        522733        13.166826  Platinum             -1.0
# 657        522733        13.166826  Platinum             -1.0
# 659        522733        13.166826  Platinum             -1.0
# 662        522733        13.166826  Platinum             -1.0
# ...           ...              ...       ...              ...
# 3299      1000000        14.128727  Platinum              0.0
# 3300      1000000        14.128727  Platinum              0.0
# 3301      1000000        14.128727  Platinum              0.0
# 3302      1000000        14.128727  Platinum              0.0
# 3303      1000000        14.128727  Platinum              0.0
#
#      prequel_featured_count_s page_views_s tier_combined
# 653                        NA           NA      Platinum
# 655                        NA           NA      Platinum
# 657                        NA           NA      Platinum
# 659                        NA           NA      Platinum
# 662                        NA           NA      Platinum
# ...                       ...          ...           ...
# 3299                       NA           NA      Platinum
# 3300                       NA           NA      Platinum
# 3301                       NA           NA      Platinum
# 3302                       NA           NA      Platinum
# 3303                       NA           NA      Platinum
#
# [484 rows x 18 columns]

# %%
from io import StringIO

dic_key_path = {'prod':'psi_first_views', 'dev':'psi_first_views/dev', 'backtest':'psi_first_views/dev'}
dic_input_bucket = {'prod':'hbo-ingest-datascience-content', 'dev':"hbo-ingest-datascience-content-dev", 'backtest':"hbo-ingest-datascience-content-dev"}
dic_output_bucket = {'prod':'hbo-outbound-datascience-content', 'dev':"hbo-outbound-datascience-content-dev", 'backtest':"hbo-outbound-datascience-content-dev"}
# input_bucket="hbo-ingest-datascience-content-dev"
# output_bucket="hbo-outbound-datascience-content-dev"

prod_backtest = 'backtest' ## 'prod', 'backtest'
key_path = dic_key_path[prod_backtest]
input_bucket = dic_input_bucket[prod_backtest]
output_bucket = dic_output_bucket[prod_backtest]

if (prod_backtest =='prod') | (prod_backtest =='dev') :
    list_date_train = [(datetime.today()).strftime('%Y-%m-%d')] 
    list_date_train = ['2022-01-01','2022-02-01','2022-03-01'] ##  ['2022-04-01','2022-05-01','2022-06-01']  #
elif prod_backtest =='backtest':
    list_date_train = ['2022-10-24']
#     list_date_train = ['2021-01-01', '2021-02-01', '2021-03-01','2021-04-01', '2021-05-01', '2021-06-01','2021-07-01', '2021-08-01', '2021-09-01']

df_pred_list = []
df_pred_decay_list = [] 
for date_train in list_date_train:
    date_pred = date_train 
    date_train_file='2022-10-24'
    #### Train 
    mode = 'train'
    logger.info(f'TRAINING MODEL FOR {date_train}, Mode:{prod_backtest}')
    
    ## Read data 
    df_raw = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_fv_{date_train_file}.csv')
    df_imdb = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_imdb_{date_train_file}.csv')
    df_talent = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_talent_{date_train_file}.csv')
    df_raw = df_raw.assign(schedule_label='beta')
    
    ## Munge features, get decay curves, resample  
    df_imdb_munged = IMDBFeatureMunger(df_imdb, mode, date_train).df_imdb_munged
    df_base_munged_decay, df_base_munged = BaseFeatureMunger(df_raw, df_imdb_munged, df_talent, mode, date_train).return_df()
    df_decay_category = FVDecay(df_base_munged_decay, mode, date_train, 'category').return_df()
    df_in_train = PreProcessor(df_base_munged, mode, date_train).return_df()  
    Utils.to_csv_s3(df_decay_category, input_bucket, key_path, f'fv_decay_category_{date_train}.csv')
    Utils.to_csv_s3(df_in_train, input_bucket, key_path, f'fv_train_munged_{date_train}.csv')
    Utils.to_csv_s3(df_in_train, 'hbo-ingest-datascience-content-dev', key_path, f'fv_train_munged_{date_train}.csv')
    
    df_in_train.assign(upload_date_time=datetime.now().strftime("%Y-%m-%d %H:%M"))
    df_in_train = df_in_train.merge(new_tier[['title_id','season_number','tier_combined']], on=['title_id','season_number'], how='left')
    df_in_train.loc[(df_in_train.tier_combined.isnull()) & (df_in_train.tier==3), 'tier_combined']='Bronze'
    df_in_train.loc[(df_in_train.tier_combined.isnull()) & (df_in_train.tier==2), 'tier_combined']='Silver'
    df_in_train.loc[(df_in_train.tier_combined.isnull()) & (df_in_train.tier==1), 'tier_combined']='Gold'
    df_in_train.loc[(df_in_train.tier_combined.isnull()) & (df_in_train.tier==0), 'tier_combined']='Platinum'
    df_in_train['tier_adj'] = df_in_train['tier_combined']
    df_in_train = df_in_train[df_in_train.title_name!='House of the Dragon']
    Utils.to_csv_s3(df_in_train, output_bucket, key_path, f'fv_train_munged.csv')
    
# #     ## Train xgb
    XGB(df_in_train, mode, date_train)
    
    #### Predict 
    mode = 'predict'
    logger.info(f'PREDICTING FOR {date_pred}, Mode:{prod_backtest}')
    df_pred_raw = Utils.read_csv_s3(input_bucket, key_path, 'cost_allocation_df_pred_20221024.csv')
    df_pred_raw['category'] = df_pred_raw['category'].str.title()
    df_pred_raw['tier_adj'] = df_pred_raw['tier']
    df_pred_raw['content_category'] = 'series'
    df_pred_raw.loc[df_pred_raw['category']=='Specials', 'content_category'] = 'special'
    df_pred_raw.loc[(df_pred_raw['category']=='Pay1') | (df_pred_raw['category']=='Scripted Features') | (df_pred_raw['category']=='Documentary Features'), 'content_category'] = 'movies'
#     df_pred_raw = df_pred_raw.drop_duplicates(subset=['title','season','category'], keep='last')
    df_in_pred = df_pred_raw[['tier_adj','category','content_category']]
    
    feature_avg = df_in_train.drop_duplicates(subset=['title_name','season_number','category'])
    feature_avg = feature_avg.groupby(['tier_adj','category','content_category'])['page_views', 'page_views_s','prequel_featured_count','prequel_featured_count_s','prequel_count_s','prequel_count'].agg(pd.Series.mode).reset_index()

    feature_avg.loc[(feature_avg.category=='Documentary Features') & (feature_avg.tier_adj=='Gold')& (feature_avg.content_category=='series'), 'page_views_s'] ='High'
    feature_avg.loc[(feature_avg.category=='Documentary Features') & (feature_avg.tier_adj=='Gold')& (feature_avg.content_category=='series'), 'prequel_featured_count_s'] ='Low'
    feature_avg.loc[(feature_avg.category=='Scripted Comedy Series') & (feature_avg.tier_adj=='Gold'), 'prequel_featured_count_s'] ='Low'
    feature_avg.loc[(feature_avg.category=='Unscripted Series') & (feature_avg.tier_adj=='Gold'), 'prequel_featured_count_s'] = 'Low'
    feature_avg.loc[(feature_avg.category=='Scripted Drama Series') & (feature_avg.tier_adj=='Platinum'), 'prequel_featured_count_s'] = 'Low'
    feature_avg.loc[(feature_avg.category=='Scripted Drama Series') & (feature_avg.tier_adj=='Gold'), 'prequel_featured_count_s'] = 'Low'
    feature_avg.loc[(feature_avg.category=='Scripted Drama Series') & (feature_avg.tier_adj=='Platinum'), 'prequel_count_s'] = 0
    feature_avg.loc[(feature_avg.category=='Scripted Features') & (feature_avg.tier_adj=='Platinum'), 'page_views'] = 'High'
    feature_avg.loc[(feature_avg.category=='Scripted Features') & (feature_avg.tier_adj=='Platinum'), 'prequel_featured_count'] = 'High'
    feature_avg.loc[(feature_avg.category=='Scripted Features') & (feature_avg.tier_adj=='Platinum'), 'prequel_count'] = 0
    feature_avg.loc[(feature_avg.category=='Unscripted Series') & (feature_avg.tier_adj=='Silver'), 'prequel_count_s'] = 0
    
    df_in_pred=df_in_pred.merge(feature_avg, on=['tier_adj','category','content_category'], how='left')
    df_in_pred.loc[(df_in_pred.category=='Pay1') & (df_in_pred.tier_adj=='Platinum'), 'page_views'] ='High'
    df_in_pred.loc[(df_in_pred.category=='Pay1') & (df_in_pred.tier_adj=='Platinum'), 'prequel_featured_count'] ='High'
    df_in_pred.loc[(df_in_pred.category=='Pay1') & (df_in_pred.tier_adj=='Platinum'), 'prequel_count'] =0.0

    df_in_pred[['prequel_count_s','prequel_count']] = df_in_pred[['prequel_count_s','prequel_count']].fillna(-1.0)
    df_in_pred = df_in_pred.fillna('NA')

    ## Predict and apply decay 
    df_out_pred = XGB(df_in_pred, mode, date_pred).return_df()
    df_pred_list.append(df_out_pred)


df_pred = pd.concat(df_pred_list)
df_pred = df_pred.drop_duplicates(subset=['content_category','category','tier_adj','first_views_log_pred'])
df_pred['tier'] =df_pred['tier_adj']
display(df_pred[['tier','category','content_category','first_views_pred']].sort_values(by=['tier']))
df_pred_final = df_pred_raw[['uncleaned_title','title','tier','season','release_month','category','content_category','source']].merge(df_pred[['content_category','category','tier','first_views_pred']], how='left')
Utils.to_csv_s3(df_pred_final, input_bucket, key_path, f'cost_allocation_df_pred_out_20221024.csv')
#     ## Read data  
#     if  (prod_backtest =='prod') | (prod_backtest =='dev') :
#         df_imdb_pred = Utils.read_csv_s3(input_bucket, key_path, f'fv_pred_{date_pred}.csv')
#         df_imdb_pred = df_imdb_pred.assign(first_views=0, title_id=0)
#         df_raw_pred = df_imdb_pred.copy()
#         df_talent_pred = Utils.read_csv_s3(input_bucket, key_path, f'fv_pred_talent_{date_pred}.csv')
#     elif prod_backtest=='backtest':
#         df_imdb_pred = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_imdb_2021-12-01.csv')
#         df_raw_pred = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_2021-12-15.csv')
#         df_talent_pred = Utils.read_csv_s3(input_bucket, key_path, f'fv_train_talent_{date_pred}.csv')
#         df_raw_pred = df_raw_pred[(df_raw_pred.effective_start_date >= date_pred)\
#                                   & (df_raw_pred.effective_start_date < datetime.strptime(date_pred, '%Y-%m-%d')+ timedelta(days=92))]
    
#     ## Munge features and resample 
#     df_imdb_munged_pred = IMDBFeatureMunger(df_imdb_pred, mode, date_pred).return_df()
#     df_base_munged_pred = BaseFeatureMunger(df_raw_pred, df_imdb_munged_pred, df_talent_pred, mode, date_pred).return_df()
#     df_in_pred = PreProcessor(df_base_munged_pred, mode, date_pred).return_df()
# Out:
# INFO:root:TRAINING MODEL FOR 2022-10-24, Mode:backtest
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_train_fv_2022-10-24.csv
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_train_imdb_2022-10-24.csv
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_train_talent_2022-10-24.csv
# INFO:root:base_data shape: (24287, 17)
# INFO:root:base_data null: Unnamed: 0                         0
# title_id                           0
# season_number                      0
# title_name                         0
# content_category                   0
# program_type                       0
# category                           0
# tier                               0
# effective_start_date               0
# effective_end_date                 0
# imdb_imdb_series_id                0
# reference_type                     0
# reference_title                    0
# reference_title_id                 0
# reference_title_type               0
# reference_reference_type        3411
# reference_reference_title_id    3411
# dtype: int64
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:root:base_data shape: (48201, 20)
# INFO:root:base_data null: Unnamed: 0                  0
# title_id                    0
# title_name                  0
# season_number               0
# content_category            0
# content_source              0
# program_type                0
# category                    0
# tier                        0
# effective_start_date        0
# request_date                0
# premiere_ind                0
# asset_premiere_count        0
# premiering_hours_runtime    1
# first_views                 0
# hours_viewed                0
# days_since_premiere         0
# days_on_platform            0
# finished_window_flag        0
# schedule_label              0
# dtype: int64
# INFO:root:title imdb shape: (530, 14)
# 156
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Saved to hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_decay_category_2022-10-24.csv
# INFO:root:Saved to hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_train_munged_2022-10-24.csv
# INFO:root:Saved to hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_train_munged_2022-10-24.csv
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Saved to hbo-outbound-datascience-content-dev/psi_first_views/dev/fv_train_munged.csv
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Saved model to hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_2022-10-24.pkl
# INFO:root:Saved to hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_2022-10-24.pkl
# INFO:root:Done model training 2022-10-24
# INFO:root:PREDICTING FOR 2022-10-24, Mode:backtest
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/cost_allocation_df_pred_20221024.csv
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:71: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# INFO:root:Reading from hbo-ingest-datascience-content-dev/psi_first_views/dev/fv_2022-10-24.pkl
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:365: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          tier                category content_category  first_views_pred
# 115    Bronze   Scripted Drama Series           series       3492.023193
# 1      Bronze    Documentary Features           movies       1232.704346
# 234    Bronze           International           series        617.829102
# 375    Bronze   Adult Animated Series           series       1232.704346
# 355    Bronze           Kids & Family           series        156.492432
# 24     Bronze       Unscripted Series           series       1073.176147
# 201    Bronze  Scripted Comedy Series           series       1325.927490
# 87     Bronze             Docu-Series           series       1133.303589
# 37     Bronze                Specials          special       1232.704346
# 379      Gold   Adult Animated Series           series      53659.421875
# 107      Gold  Scripted Comedy Series           series      64309.437500
# 25       Gold       Unscripted Series           series      53659.421875
# 18       Gold   Scripted Drama Series           series      45585.085938
# 368      Gold       Scripted Features           movies      63068.105469
# 9        Gold             Docu-Series           series      42698.195312
# 347      Gold    Documentary Features           movies     122989.046875
# 183      Gold                Specials          special      79746.242188
# 417  Platinum  Scripted Comedy Series           series     436221.218750
# 116  Platinum   Scripted Drama Series           series     436221.218750
# 35     Silver                Specials          special       5567.542969
# 22     Silver       Unscripted Series           series       8059.431641
# 367    Silver       Scripted Features           movies       9439.294922
# 16     Silver  Scripted Comedy Series           series       7645.609863
# 13     Silver             Docu-Series           series       5686.716797
# 377    Silver   Adult Animated Series           series       7645.609863
# 133    Silver   Scripted Drama Series           series      11497.808594
# 0      Silver    Documentary Features           movies       5764.581055
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Saved to hbo-outbound-datascience-content-dev/psi_first_views/dev/cost_allocation_df_pred_out_20221024.csv

# %%
Utils.to_csv_s3(df_pred_final, input_bucket, key_path, f'cost_allocation_df_pred_out_20221024.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# INFO:root:Saved to hbo-ingest-datascience-content-dev/psi_first_views/dev/cost_allocation_df_pred_out_20221024.csv

# %%
df_in_train.sort_values(by=['effective_start_date'], ascending=False)
# Out:
#           title_name               title_id  season_number  tier  \
# 2429  Katrina Babies  GYtrYcQqGpUqupQEAAAp5              0     3
# 3209     House of Ho  GXvTTlQwJdcLDGQEAAAMj              2     2
# 3126     House of Ho  GXvTTlQwJdcLDGQEAAAMj              2     2
# 2466  Katrina Babies  GYtrYcQqGpUqupQEAAAp5              0     3
# 3164     House of Ho  GXvTTlQwJdcLDGQEAAAMj              2     2
# ...              ...                    ...            ...   ...
# 1335       Legendary  GXsRXGAJrtsPDFwEAAAAC              1     2
# 1333       Legendary  GXsRXGAJrtsPDFwEAAAAC              1     2
# 1332       Legendary  GXsRXGAJrtsPDFwEAAAAC              1     2
# 1329       Legendary  GXsRXGAJrtsPDFwEAAAAC              1     2
# 722        Love Life  GXrxUzQ5VqrGGtAEAAAAd              1     1
#
#      content_category                category effective_start_date  \
# 2429           movies    Documentary Features           2022-08-25
# 3209           series       Unscripted Series           2022-08-25
# 3126           series       Unscripted Series           2022-08-25
# 2466           movies    Documentary Features           2022-08-25
# 3164           series       Unscripted Series           2022-08-25
# ...               ...                     ...                  ...
# 1335           series       Unscripted Series           2020-05-27
# 1333           series       Unscripted Series           2020-05-27
# 1332           series       Unscripted Series           2020-05-27
# 1329           series       Unscripted Series           2020-05-27
# 722            series  Scripted Comedy Series           2020-05-27
#
#      schedule_label  prequel_count prequel_featured_count page_views  \
# 2429           beta            0.0                     NA         NA
# 3209           beta           -1.0                     NA         NA
# 3126           beta           -1.0                     NA         NA
# 2466           beta            0.0                     NA         NA
# 3164           beta           -1.0                     NA         NA
# ...             ...            ...                    ...        ...
# 1335           beta           -1.0                     NA         NA
# 1333           beta           -1.0                     NA         NA
# 1332           beta           -1.0                     NA         NA
# 1329           beta           -1.0                     NA         NA
# 722            beta           -1.0                     NA         NA
#
#       first_views  first_views_log tier_adj  prequel_count_s  \
# 2429         5208         8.557951   Bronze             -1.0
# 3209         1976         7.588830   Silver              0.0
# 3126         1976         7.588830   Silver              0.0
# 2466         5208         8.557951   Bronze             -1.0
# 3164         1976         7.588830   Silver              0.0
# ...           ...              ...      ...              ...
# 1335        98598        11.498806     Gold              0.0
# 1333        98598        11.498806     Gold              0.0
# 1332        98598        11.498806     Gold              0.0
# 1329        98598        11.498806     Gold              0.0
# 722        241951        12.396491     Gold              0.0
#
#      prequel_featured_count_s page_views_s tier_combined
# 2429                       NA           NA        Bronze
# 3209                       NA           NA        Silver
# 3126                       NA           NA        Silver
# 2466                       NA           NA        Bronze
# 3164                       NA           NA        Silver
# ...                       ...          ...           ...
# 1335                      Low           NA          Gold
# 1333                      Low           NA          Gold
# 1332                      Low           NA          Gold
# 1329                      Low           NA          Gold
# 722                       Low           NA          Gold
#
# [3775 rows x 18 columns]

# %%
df_eval = df_in_train_full.drop_duplicates(subset=['title_name','season_number','category'])
df_eval = df_eval[(df_eval.effective_start_date>='2022-01-01') & (df_eval.effective_start_date<='2022-07-01') & (df_eval.tier_adj=='Gold')]
df_eval.sort_values(by=['first_views'])
# Out:
#                                         title_name               title_id  \
# 2524                        West Side Story (2021)  GYf0-iQ1eoRKojgEAAAAC
# 2429                                           DMZ  GYhA0QwXRB2quwwEAAACg
# 2430                                    Tokyo Vice  GYilRbQBlfrurwgEAAAH0
# 2437                      The Time Traveler's Wife  GYjCvngVdSMN1qAEAAABb
# 2071                       The Righteous Gemstones  GXRuC4gJdpm2YwgEAAAF_
# 2523                                The King's Man  GYeGXugg4ewPCwgEAABi1
# 2072                          Our Flag Means Death  GYf3LzwJV98JifQEAAAAO
# 2521                     Hitman's Wife's Bodyguard  GYabfeQrMwLqFugEAAAAC
# 2522                                      Free Guy  GYdYmPQZFO7eZGAEAAAAT
# 3589                                     Westworld  GV7xwpQNK8MJfPwEAAAG_
# 2939                              We Own This City  GYh5pMgWVA8LDdQEAAACt
# 3581                          The Flight Attendant  GX5MHsQzwwIuLwgEAAACp
# 2527                                          Dune  GYUjdLgBiJp5otAEAAAAJ
# 2843                           Father of the Bride  GYnXC6AfPOsPCwgEAAAAb
# 2526                             F9: The Fast Saga  GYfim_QUVfBqboQEAAAC-
# 3583                                 The Staircase  GYk93MwWuH4BJoAEAAABu
# 3582  Winning Time: The Rise of the Lakers Dynasty  GYbDO6QFHOsPCwgEAAAMR
# 3588                                The Gilded Age  GYZLijQsvoJKWWQEAAAB6
# 3671                                    The Batman  GYiDbSAmIpMNvYAEAAAAI
#
#       season_number  tier content_category                category  \
# 2524              0     1           movies                    Pay1
# 2429              1     2           series   Scripted Drama Series
# 2430              1     2           series   Scripted Drama Series
# 2437              1     2           series   Scripted Drama Series
# 2071              2     2           series  Scripted Comedy Series
# 2523              0     1           movies                    Pay1
# 2072              1     2           series  Scripted Comedy Series
# 2521              0     1           movies                    Pay1
# 2522              0     1           movies                    Pay1
# 3589              4     1           series   Scripted Drama Series
# 2939              1     3           series   Scripted Drama Series
# 3581              2     1           series   Scripted Drama Series
# 2527              0     1           movies                    Pay1
# 2843              0     1           movies       Scripted Features
# 2526              0     1           movies                    Pay1
# 3583              1     1           series   Scripted Drama Series
# 3582              1     1           series   Scripted Drama Series
# 3588              1     1           series   Scripted Drama Series
# 3671              0     1           movies                 Popcorn
#
#      effective_start_date schedule_label  prequel_count  \
# 2524           2022-03-02           beta            1.0
# 2429           2022-03-17           beta           -1.0
# 2430           2022-04-07           beta           -1.0
# 2437           2022-05-16           beta           -1.0
# 2071           2022-01-10           beta           -1.0
# 2523           2022-02-18           beta            2.0
# 2072           2022-03-03           beta           -1.0
# 2521           2022-01-07           beta            1.0
# 2522           2022-02-23           beta            0.0
# 3589           2022-06-27           beta           -1.0
# 2939           2022-04-26           beta           -1.0
# 3581           2022-04-21           beta           -1.0
# 2527           2022-03-10           beta            1.0
# 2843           2022-06-16           beta            2.0
# 2526           2022-03-04           beta            5.0
# 3583           2022-05-05           beta           -1.0
# 3582           2022-03-07           beta           -1.0
# 3588           2022-01-25           beta           -1.0
# 3671           2022-04-18           beta            5.0
#
#      prequel_featured_count page_views  first_views  first_views_log tier_adj  \
# 2524                   High       High        12782         9.455793     Gold
# 2429                     NA         NA        14574         9.586994     Gold
# 2430                     NA         NA        26886        10.199361     Gold
# 2437                     NA         NA        27350        10.216472     Gold
# 2071                     NA         NA        40069        10.598358     Gold
# 2523                   High       High        47360        10.765533     Gold
# 2072                     NA         NA        47861        10.776056     Gold
# 2521                    Med       High        48271        10.784586     Gold
# 2522                     NA       High        49485        10.809425     Gold
# 3589                     NA         NA        51345        10.846323     Gold
# 2939                     NA         NA        53537        10.888128     Gold
# 3581                     NA         NA        53554        10.888446     Gold
# 2527                   High       High        57415        10.958061     Gold
# 2843                    Med       High        66353        11.102744     Gold
# 2526                   High       High        78802        11.274694     Gold
# 3583                     NA         NA        88016        11.385274     Gold
# 3582                     NA         NA       113968        11.643673     Gold
# 3588                     NA         NA       141959        11.863294     Gold
# 3671                   High       High       436723        12.987054     Gold
#
#       prequel_count_s prequel_featured_count_s page_views_s tier_combined
# 2524             -1.0                       NA           NA          Gold
# 2429              0.0                       NA         High          Gold
# 2430              0.0                       NA         High          Gold
# 2437              0.0                       NA           NA          Gold
# 2071              0.0                       NA         High          Gold
# 2523             -1.0                       NA           NA          Gold
# 2072              0.0                       NA         High          Gold
# 2521             -1.0                       NA           NA          Gold
# 2522             -1.0                       NA           NA          Gold
# 3589              4.0                     High         High          Gold
# 2939              0.0                       NA           NA          Gold
# 3581              1.0                      Low         High          Gold
# 2527             -1.0                       NA           NA          Gold
# 2843             -1.0                       NA           NA          Gold
# 2526             -1.0                       NA           NA          Gold
# 3583              0.0                      Low         High          Gold
# 3582              0.0                       NA           NA          Gold
# 3588              0.0                       NA           NA          Gold
# 3671             -1.0                       NA           NA          Gold

# %%
df_pred_full = df_pred.copy()
## Q1 2022 
df_eval = df_in_train_full.drop_duplicates(subset=['title_name','season_number','category'])
df_eval = df_eval[(df_eval.effective_start_date>='2022-01-01') & (df_eval.effective_start_date<='2022-04-01')]
df_eval['pred_date'] =  df_eval['effective_start_date'].dt.to_period('M').dt.to_timestamp()
df_eval_ = df_eval.merge(df_pred_full, on=['content_category','category','tier_adj','pred_date'], how='left')
df_eval_ = df_eval_.groupby(by=['tier_adj']).agg({'first_views':'sum', 'first_views_pred':'sum', 'title_name':'count'}).reset_index()
df_eval_ = df_eval_.sort_values(by=['tier_adj']).dropna()
df_eval_.loc['total']= df_eval_.sum(numeric_only=True, axis=0)
df_eval_['diff'] = df_eval_['first_views_pred'] - df_eval_['first_views']
df_eval_['error'] = df_eval_['diff'] / df_eval_['first_views']

display(df_eval_)
# Out:
#        tier_adj  first_views  first_views_pred  title_name           diff  \
# 0        Bronze      49772.0      3.078968e+04        25.0  -18982.320312
# 1          Gold     652546.0      7.687819e+05        11.0  116235.937500
# 2      Platinum    1240826.0      1.308509e+06         3.0   67682.750000
# 3        Silver     412154.0      3.276675e+05        29.0  -84486.468750
# total       NaN    2355298.0      2.435748e+06        68.0   80450.000000
#
#           error
# 0     -0.381386
# 1      0.178127
# 2      0.054547
# 3     -0.204988
# total  0.034157

# %%
df_pred_full = df_pred.copy()
## Q2 2022 
df_eval = df_in_train_full.drop_duplicates(subset=['title_name','season_number','category'])
df_eval = df_eval[(df_eval.effective_start_date>='2022-04-01') & (df_eval.effective_start_date<='2022-07-01')]
df_eval['pred_date'] =  df_eval['effective_start_date'].dt.to_period('M').dt.to_timestamp()
df_eval_ = df_eval.merge(df_pred_full, on=['content_category','category','tier_adj','pred_date'], how='left')
df_eval_ = df_eval_.groupby(by=['tier_adj']).agg({'first_views':'sum', 'first_views_pred':'sum', 'title_name':'count'}).reset_index()
df_eval_ = df_eval_.sort_values(by=['tier_adj']).dropna()
df_eval_.loc['total']= df_eval_.sum(numeric_only=True, axis=0)
df_eval_['diff'] = df_eval_['first_views_pred'] - df_eval_['first_views']
df_eval_['error'] = df_eval_['diff'] / df_eval_['first_views']

display(df_eval_)
# Out:
#       tier_adj  first_views  first_views_pred  title_name           diff  \
# 0       Bronze      51567.0      33014.382812        18.0  -18552.617188
# 1         Gold     803764.0     587208.875000         8.0 -216555.125000
# 2       Silver     462213.0     295427.468750        30.0 -166785.531250
# total      NaN    1317544.0     915650.750000        56.0 -401893.250000
#
#           error
# 0     -0.359777
# 1     -0.269426
# 2     -0.360841
# total -0.305032

# %%
df_title = df_eval.merge(df_pred_full, on=['content_category','category','tier_adj','pred_date'], how='left')
df_title['abs_diff'] =  abs(df_title['first_views'] - df_title['first_views_pred'])
df_title[['title_name','category','tier_adj','first_views','first_views_pred', 'abs_diff']].sort_values(by=['abs_diff'], ascending=False).head(10)
# Out:
#                                            title_name                category  \
# 66                                         Peacemaker   Scripted Drama Series
# 51                                           Euphoria   Scripted Drama Series
# 56  Harry Potter 20th Anniversary: Return to Hogwarts           Kids & Family
# 67                                     The Gilded Age   Scripted Drama Series
# 37                                                DMZ   Scripted Drama Series
# 60                                        The Fallout       Scripted Features
# 42                             West Side Story (2021)                    Pay1
# 64       Winning Time: The Rise of the Lakers Dynasty   Scripted Drama Series
# 22                            The Righteous Gemstones  Scripted Comedy Series
# 39                                  F9: The Fast Saga                    Pay1
#
#     tier_adj  first_views  first_views_pred       abs_diff
# 66  Platinum       178666     525257.687500  346591.687500
# 51  Platinum       728229     525257.687500  202971.312500
# 56  Platinum       333931     525257.687500  191326.687500
# 67      Gold       141959      75880.539062   66078.460938
# 37      Gold        14574      79152.750000   64578.750000
# 60    Silver        64195       9084.852539   55110.147461
# 42      Gold        12782      54532.195312   41750.195312
# 64      Gold       113968      79152.750000   34815.250000
# 22      Gold        40069      67513.625000   27444.625000
# 39      Gold        78802      54532.195312   24269.804688

# %%
df_title = df_eval.merge(df_pred_full, on=['content_category','category','tier_adj','pred_date'], how='left')
df_title['abs_diff'] =  abs(df_title['first_views'] - df_title['first_views_pred'])
df_title[['title_name','category','tier_adj','first_views','first_views_pred', 'abs_diff']].sort_values(by=['abs_diff'], ascending=False).head(10)
# Out:
#                   title_name                category tier_adj  first_views  \
# 36                Tokyo Vice   Scripted Drama Series     Gold        26886
# 35  The Time Traveler's Wife   Scripted Drama Series     Gold        27350
# 44          We Own This City   Scripted Drama Series     Gold        53537
# 53      The Flight Attendant   Scripted Drama Series     Gold        53554
# 8                        Old                    Pay1   Silver        49791
# 52                 Westworld   Scripted Drama Series     Gold        51345
# 41       Father of the Bride       Scripted Features     Gold        66353
# 16                     Barry  Scripted Comedy Series   Silver        28118
# 55              The Survivor       Scripted Features   Silver         5037
# 42            Gentleman Jack   Scripted Drama Series   Silver         5761
#
#     first_views_pred      abs_diff
# 36      96246.007812  69360.007812
# 35      83377.828125  56027.828125
# 44      96246.007812  42709.007812
# 53      96246.007812  42692.007812
# 8       13134.992188  36656.007812
# 52      72932.140625  21587.140625
# 41      87378.039062  21025.039062
# 16       7344.336426  20773.663574
# 55      22810.082031  17773.082031
# 42      22164.423828  16403.423828

# %%
df_eval = df_in_train.drop_duplicates(subset=['title_name','season_number','category'])
df_eval = df_eval[(df_eval.effective_start_date>='2022-04-01') & (df_eval.effective_start_date<='2022-07-01')]
df_eval
# Out:
#                                              title_name  \
# 1739                                           The Baby
# 1740                                        The Garcias
# 1744                           A Black Lady Sketch Show
# 1758                              That Damn Michael Che
# 1835                                 PAUSE with Sam Jay
# 1923                     George Carlin's American Dream
# 1926          Roadrunner: A Film About Anthony Bourdain
# 2015                                                Old
# 2019                          The Matrix: Resurrections
# 2021                                         Blue Bayou
# 2022                                   The Card Counter
# 2023                                  The Forever Purge
# 2024                                   Dear Evan Hansen
# 2044                                    The Night House
# 2051                                 Last Night in Soho
# 2061                                              Hacks
# 2066                                      Made For Love
# 2070                                              Barry
# 2073                                       Close Enough
# 2152                              Menudo: Forever Young
# 2155                                The Invisible Pilot
# 2189                                      Not So Pretty
# 2245                       Jerrod Carmichael: Rothaniel
# 2247                              Bill Maher: #Adulting
# 2249             Marlon Wayans Presents: The Headliners
# 2343               Spring Awakening: Those You've Known
# 2346                                         Endangered
# 2348                          Chernobyl: The Lost Tapes
# 2349               Tony Hawk: Until the Wheels Fall Off
# 2351                                            Navalny
# 2359                                          The Janes
# 2428                           The Time Traveler's Wife
# 2438                                         Tokyo Vice
# 2566                                  The Dog House: UK
# 2571                       The Great Pottery Throw Down
# 2574                                         The Bridge
# 2750        Fantastic Beasts: The Secrets of Dumbledore
# 2842                                Father of the Bride
# 2934                                     Gentleman Jack
# 2935                                           Irma Vep
# 2938                                   We Own This City
# 3026                                 Gordita Chronicles
# 3027  Naked Mole Rat Gets Dressed: The Underground R...
# 3032                                        Tig n' Seek
# 3397                                          Legendary
# 3488                                   Mind Over Murder
# 3579                                          Westworld
# 3580                               The Flight Attendant
# 3581                                      The Staircase
# 3670                                         The Batman
# 3854                                       The Survivor
#
#                    title_id  season_number  tier content_category  \
# 1739  GYhaucgZnkLtZpAEAAAAC              1     3           series
# 1740  GYjOSDwMrdwSGmQEAAAB1              1     3           series
# 1744  GXRt2ogky7r29bAEAAAGe              3     3           series
# 1758  GYG8_bgHgxWvDIwEAAACA              2     3           series
# 1835  GYIrcGwCEe6esYgEAAAAI              2     3           series
# 1923  GYmrTxAWpCl3DMgEAAAAC              1     2           series
# 1926  GYn1GYQpzpKtzhQEAAARe              0     2           movies
# 2015  GYiaPwAgBBJuGtwEAAAFs              0     2           movies
# 2019  GYbD1_wnm3mDCwgEAAAPM              0     2           movies
# 2021  GYm0w6AY16rM7wgEAAADM              0     3           movies
# 2022  GYnEqqwAqmj3DwwEAAAAD              0     3           movies
# 2023  GYgbcAQusfLYbrQEAAAeJ              0     2           movies
# 2024  GYijk0Qxbh5mGSwEAAAHI              0     2           movies
# 2044  GYf0z_wyIUiisRgEAAAAl              0     3           movies
# 2051  GYm0w5wSRXaTDYQEAAAD4              0     3           movies
# 2061  GYIBToQrPdotpNQEAAAEa              2     2           series
# 2066  GYFE2Tg8P-76tMQEAAAAS              2     2           series
# 2070  GWmKDEwGrA8JInwEAAAL6              3     2           series
# 2073  GXtviwAI5ZJuSkwEAAAa4              3     2           series
# 2152  GYnv4ygWtS1itRwEAAANQ              1     3           series
# 2155  GYertfwheoomXpgEAAAAb              1     3           series
# 2189  GYjJrvg7QksLDwgEAAAAG              1     3           series
# 2245  GYjTxLwCPgSiOTwEAAACn              0     3          special
# 2247  GYkMhfQ2aisPCIAEAAAAC              0     3          special
# 2249  GYkWyigApiMPCFwEAAAAE              0     3          special
# 2343  GYlBRpQSlXox_gAEAAAAw              0     3           movies
# 2346  GYpthCgM-PsILwgEAAAAY              0     3           movies
# 2348  GYpn_qwcoS53DZgEAAAAZ              0     3           movies
# 2349  GYiYW1gEfPke9GQEAAAFB              0     3           movies
# 2351  GYmFp9ATv1JSBmwEAAACW              0     3           movies
# 2359  GYnLUBAj-sZN_YgEAAAHN              0     3           movies
# 2428  GYjCvngVdSMN1qAEAAABb              1     2           series
# 2438  GYilRbQBlfrurwgEAAAH0              1     2           series
# 2566  GXuqhmQVncQq_tgEAAAJc              3     3           series
# 2571  GX0gQ9AKAgr5cuAEAAAG_              5     3           series
# 2574  GYBMTBAxniqsjwwEAAAAR              2     3           series
# 2750  GYij31wBohZA3MQEAAAKa              0     2           movies
# 2842  GYnXC6AfPOsPCwgEAAAAb              0     1           movies
# 2934  GXI-WvQqTfKuWIwEAAAAC              2     3           series
# 2935  GYmcIcA5b-IyOtwEAAAAC              1     3           series
# 2938  GYh5pMgWVA8LDdQEAAACt              1     3           series
# 3026  GYnl_JQsLosPCwgEAAACs              1     3           series
# 3027  GYpektwzVLYqIrwEAAAAC              0     3          special
# 3032  GXuFAsAdPy8PCwgEAAAyj              4     3           series
# 3397  GXsRXGAJrtsPDFwEAAAAC              3     2           series
# 3488  GYp4MpAPtALoDwwEAAAAq              1     2           series
# 3579  GV7xwpQNK8MJfPwEAAAG_              4     1           series
# 3580  GX5MHsQzwwIuLwgEAAACp              2     1           series
# 3581  GYk93MwWuH4BJoAEAAABu              1     1           series
# 3670  GYiDbSAmIpMNvYAEAAAAI              0     1           movies
# 3854  GYh5pqwC3YbQkKQEAAACu              0     3           movies
#
#                     category effective_start_date schedule_label  \
# 1739  Scripted Comedy Series           2022-04-25           beta
# 1740  Scripted Comedy Series           2022-04-14           beta
# 1744  Scripted Comedy Series           2022-04-09           beta
# 1758  Scripted Comedy Series           2022-05-26           beta
# 1835       Unscripted Series           2022-05-21           beta
# 1923    Documentary Features           2022-05-21           beta
# 1926    Documentary Features           2022-06-09           beta
# 2015                    Pay1           2022-05-13           beta
# 2019                    Pay1           2022-05-10           beta
# 2021                    Pay1           2022-06-24           beta
# 2022                    Pay1           2022-06-10           beta
# 2023                    Pay1           2022-04-15           beta
# 2024                    Pay1           2022-05-06           beta
# 2044                    Pay1           2022-04-08           beta
# 2051                    Pay1           2022-07-01           beta
# 2061  Scripted Comedy Series           2022-05-12           beta
# 2066  Scripted Comedy Series           2022-04-28           beta
# 2070  Scripted Comedy Series           2022-04-25           beta
# 2073  Scripted Comedy Series           2022-04-07           beta
# 2152             Docu-Series           2022-06-23           beta
# 2155             Docu-Series           2022-04-05           beta
# 2189             Docu-Series           2022-04-14           beta
# 2245                Specials           2022-04-02           beta
# 2247                Specials           2022-04-16           beta
# 2249                Specials           2022-04-21           beta
# 2343    Documentary Features           2022-05-04           beta
# 2346    Documentary Features           2022-06-29           beta
# 2348    Documentary Features           2022-06-23           beta
# 2349    Documentary Features           2022-04-06           beta
# 2351    Documentary Features           2022-05-26           beta
# 2359    Documentary Features           2022-06-09           beta
# 2428   Scripted Drama Series           2022-05-16           beta
# 2438   Scripted Drama Series           2022-04-07           beta
# 2566           International           2022-06-16           beta
# 2571           International           2022-04-14           beta
# 2574           International           2022-06-30           beta
# 2750                 Popcorn           2022-05-30           beta
# 2842       Scripted Features           2022-06-16           beta
# 2934   Scripted Drama Series           2022-04-26           beta
# 2935   Scripted Drama Series           2022-06-07           beta
# 2938   Scripted Drama Series           2022-04-26           beta
# 3026           Kids & Family           2022-06-23           beta
# 3027           Kids & Family           2022-06-30           beta
# 3032           Kids & Family           2022-05-26           beta
# 3397       Unscripted Series           2022-05-19           beta
# 3488             Docu-Series           2022-06-21           beta
# 3579   Scripted Drama Series           2022-06-27           beta
# 3580   Scripted Drama Series           2022-04-21           beta
# 3581   Scripted Drama Series           2022-05-05           beta
# 3670                 Popcorn           2022-04-18           beta
# 3854       Scripted Features           2022-04-28           beta
#
#       prequel_count prequel_featured_count page_views  first_views  \
# 1739           -1.0                     NA         NA         5828
# 1740           -1.0                     NA         NA         1077
# 1744           -1.0                     NA         NA         4145
# 1758           -1.0                     NA         NA          953
# 1835           -1.0                     NA         NA          428
# 1923           -1.0                     NA         NA        11423
# 1926            0.0                     NA       High         4818
# 2015            0.0                     NA       High        49791
# 2019            5.0                   High       High        24081
# 2021            0.0                     NA         NA         2311
# 2022            0.0                     NA         NA         8697
# 2023            5.0                    Low       High        32411
# 2024            0.0                     NA       High         5830
# 2044            0.0                     NA         NA        15219
# 2051            0.0                     NA         NA         8507
# 2061           -1.0                     NA         NA        19380
# 2066           -1.0                     NA         NA         3207
# 2070           -1.0                     NA         NA        28118
# 2073           -1.0                     NA         NA         2211
# 2152           -1.0                     NA         NA         4221
# 2155           -1.0                     NA         NA         4917
# 2189           -1.0                     NA         NA        11358
# 2245           -1.0                     NA         NA         5398
# 2247           -1.0                     NA         NA         4483
# 2249           -1.0                     NA         NA         5465
# 2343            0.0                     NA         NA         2385
# 2346            0.0                     NA         NA          546
# 2348            0.0                     NA         NA         4424
# 2349            0.0                     NA         NA         7934
# 2351            0.0                     NA         NA         1933
# 2359            0.0                     NA         NA         2046
# 2428           -1.0                     NA         NA        27350
# 2438           -1.0                     NA         NA        26886
# 2566           -1.0                     NA         NA          116
# 2571           -1.0                     NA         NA         2076
# 2574           -1.0                     NA         NA           67
# 2750            2.0                    Low       High       149532
# 2842            2.0                    Med       High        66353
# 2934           -1.0                     NA         NA         5761
# 2935           -1.0                     NA         NA         4871
# 2938           -1.0                     NA         NA        53537
# 3026           -1.0                     NA         NA         6301
# 3027           -1.0                     NA         NA          334
# 3032           -1.0                     NA         NA           21
# 3397           -1.0                     NA         NA        15174
# 3488           -1.0                     NA         NA         9997
# 3579           -1.0                     NA         NA        51345
# 3580           -1.0                     NA         NA        53554
# 3581           -1.0                     NA         NA        88016
# 3670            5.0                   High       High       436723
# 3854            0.0                     NA         NA         5037
#
#       first_views_log tier_adj  prequel_count_s prequel_featured_count_s  \
# 1739         8.670429   Silver              0.0                       NA
# 1740         6.981935   Bronze              1.0                       NA
# 1744         8.329658   Bronze              2.0                       NA
# 1758         6.859615   Bronze              1.0                       NA
# 1835         6.059123   Bronze              0.0                       NA
# 1923         9.343384   Silver              0.0                       NA
# 1926         8.480114   Silver             -1.0                       NA
# 2015        10.815590   Silver             -1.0                       NA
# 2019        10.089178   Silver             -1.0                       NA
# 2021         7.745436   Bronze             -1.0                       NA
# 2022         9.070733   Bronze             -1.0                       NA
# 2023        10.386253   Silver             -1.0                       NA
# 2024         8.670772   Silver             -1.0                       NA
# 2044         9.630300   Bronze             -1.0                       NA
# 2051         9.048645   Bronze             -1.0                       NA
# 2061         9.871997   Silver              1.0                      Low
# 2066         8.073091   Silver              1.0                      Low
# 2070        10.244165   Silver              2.0                      Med
# 2073         7.701200   Bronze              2.0                      Low
# 2152         8.347827   Silver              0.0                       NA
# 2155         8.500454   Silver              0.0                       NA
# 2189         9.337678   Silver              0.0                       NA
# 2245         8.593784   Silver              0.0                       NA
# 2247         8.408048   Silver              0.0                       NA
# 2249         8.606119   Silver              0.0                       NA
# 2343         7.776954   Bronze             -1.0                       NA
# 2346         6.302619   Bronze             -1.0                       NA
# 2348         8.394800   Silver             -1.0                       NA
# 2349         8.978913   Silver             -1.0                       NA
# 2351         7.566828   Silver             -1.0                       NA
# 2359         7.623642   Bronze             -1.0                       NA
# 2428        10.216472     Gold              0.0                       NA
# 2438        10.199361     Gold              0.0                       NA
# 2566         4.753590   Bronze              2.0                       NA
# 2571         7.638198   Bronze              0.0                       NA
# 2574         4.204693   Bronze              0.0                       NA
# 2750        11.915266   Silver             -1.0                       NA
# 2842        11.102744     Gold             -1.0                       NA
# 2934         8.658866   Silver              1.0                       NA
# 2935         8.491055   Silver              0.0                       NA
# 2938        10.888128     Gold              0.0                       NA
# 3026         8.748464   Silver              0.0                       NA
# 3027         5.811141   Bronze              0.0                       NA
# 3032         3.044522   Bronze              0.0                       NA
# 3397         9.627339   Silver              2.0                      Low
# 3488         9.210040   Silver              0.0                       NA
# 3579        10.846323     Gold              4.0                     High
# 3580        10.888446     Gold              1.0                      Low
# 3581        11.385274     Gold              0.0                      Low
# 3670        12.987054     Gold             -1.0                       NA
# 3854         8.524566   Silver             -1.0                       NA
#
#      page_views_s tier_combined
# 1739           NA        Silver
# 1740           NA        Bronze
# 1744           NA        Bronze
# 1758           NA        Bronze
# 1835           NA        Bronze
# 1923           NA        Silver
# 1926           NA        Silver
# 2015           NA        Silver
# 2019           NA        Silver
# 2021           NA        Bronze
# 2022           NA        Bronze
# 2023           NA        Silver
# 2024           NA        Silver
# 2044           NA        Bronze
# 2051           NA        Bronze
# 2061         High        Silver
# 2066         High        Silver
# 2070         High        Silver
# 2073         High        Bronze
# 2152           NA        Silver
# 2155           NA        Silver
# 2189           NA        Silver
# 2245           NA        Silver
# 2247           NA        Silver
# 2249           NA        Silver
# 2343           NA        Bronze
# 2346           NA        Bronze
# 2348           NA        Silver
# 2349           NA        Silver
# 2351           NA        Silver
# 2359           NA        Bronze
# 2428           NA          Gold
# 2438         High          Gold
# 2566           NA        Bronze
# 2571           NA        Bronze
# 2574           NA        Bronze
# 2750           NA        Silver
# 2842           NA          Gold
# 2934           NA        Silver
# 2935           NA        Silver
# 2938           NA          Gold
# 3026           NA        Silver
# 3027           NA        Bronze
# 3032           NA        Bronze
# 3397          Low        Silver
# 3488           NA        Silver
# 3579         High          Gold
# 3580         High          Gold
# 3581         High          Gold
# 3670           NA          Gold
# 3854           NA        Silver

# %%
df_in_train.drop_duplicates(subset=['title_name','season_number','category']).groupby(by=['tier_combined','category','content_category'])[['tier_combined','category','content_category','first_views']].median()
# Out:
#                                                        first_views
# tier_combined category               content_category
# Bronze        Docu-Series            series                 1852.5
#               Documentary Features   movies                 1413.0
#                                      series                 2335.0
#               International          movies                  170.5
#                                      series                  908.0
#                                      special                   5.0
#               Kids & Family          series                  710.0
#                                      special                 783.0
#               Pay1                   movies                 8697.0
#               Scripted Comedy Series series                 2124.5
#               Scripted Drama Series  series                 2966.0
#               Specials               special                1233.0
#               Unscripted Series      movies                 5533.0
#                                      series                 1847.0
# Gold          Docu-Series            series                48572.0
#               Documentary Features   movies               200464.0
#                                      series                96925.0
#               Kids & Family          series                98342.0
#               Pay1                   movies                49485.0
#               Popcorn                movies               174263.5
#               Scripted Comedy Series series                70671.0
#               Scripted Drama Series  series                88016.0
#               Scripted Features      movies               112558.0
#               Specials               special              119528.5
#               Unscripted Series      series                99377.0
# Platinum      Kids & Family          special              333931.0
#               Popcorn                movies               637673.0
#               Scripted Comedy Series series               709565.0
#               Scripted Drama Series  series               545011.5
#               Scripted Features      movies               762257.0
#               Specials               special              625955.5
# Silver        Docu-Series            movies                 6542.0
#                                      series                 8217.0
#               Documentary Features   movies                 6958.0
#                                      series                 5312.0
#               International          movies                 3911.0
#                                      series                 8265.0
#               Kids & Family          series                 9059.0
#               Pay1                   movies                26127.0
#               Popcorn                movies               149532.0
#               Scripted Comedy Series series                12138.0
#               Scripted Drama Series  series                25067.0
#               Scripted Features      movies                24265.0
#               Specials               special                6091.0
#               Unscripted Series      series                12253.0

# %%
def get_agg_first_views(df_in, agg_col, grpby_title, first_view_date_col, first_view_col):
    grpby_title_agg = grpby_title + [agg_col]
    df_in[first_view_date_col] = pd.to_datetime(df_in[first_view_date_col])
    df_in['first_view_quarter'] = df_in[first_view_date_col].dt.to_period("Q").dt.to_timestamp()   
    df_in['first_view_month'] = df_in[first_view_date_col].dt.to_period('M').dt.to_timestamp()
    df_in = df_in[grpby_title_agg + first_view_col].groupby(by=grpby_title_agg).sum().reset_index()
    return df_in

dic_rename = {'tier_adj':'tier_adjusted', 'effective_start_date':'premiere_date', 'pred_date':'model_train_date'} 
out_col = ['title_name', 'first_view_month', 'premiere_date', 'season_number',
           'tier','content_category', 'category', 'prequel_count', 'prequel_featured_count','prequel_featured_count_s', 'prequel_count_s', 'page_views_s',
            'page_views', 'tier_adjusted', 'first_views_pred_decay', 'model_train_date','schedule_label']

dtype = {'season_number':int}

if  (prod_backtest =='prod') | (prod_backtest =='dev'):
    agg_var = 'first_view_month'    
    df_pred_future_out = df_pred_decay.rename(columns=dic_rename)
    df_pred_future_out = df_pred_future_out[df_pred_future_out.premiere_date>=date_pred]
    df_pred_future_out = df_pred_future_out[out_col].groupby(by=out_col[:-3]+['model_train_date', 'schedule_label']).sum().reset_index()
    df_pred_future_out = df_pred_future_out[out_col].set_index('title_name')
    df_pred_future_out['season_number'] = df_pred_future_out['season_number'].astype(int)
    Utils.to_csv_s3(df_pred_future_out, output_bucket, key_path, f'psi_monthly_xgb_forecast.csv')
    
display(df_pred_future_out.head(2))
# display(df_pred_future_out[(df_pred_future_out.tier<=1)].groupby(by=['title_name']+out_col[2:-3]+['schedule_label']).sum().reset_index().sort_values(by=['premiere_date']))
display(df_pred_future_out[(df_pred_future_out.tier<1)].groupby(by=['title_name']+out_col[2:-3]+['schedule_label']).sum().reset_index().sort_values(by=['first_views_pred_decay']))
display(df_pred_future_out[(df_pred_future_out.tier==1) & (df_pred_future_out.content_category=='series')].groupby(by=['title_name']+out_col[2:-3]+['schedule_label']).sum().reset_index().sort_values(by=['first_views_pred_decay']))
display(df_pred_future_out[(df_pred_future_out.tier<=1) & (df_pred_future_out.content_category=='movies')].groupby(by=['title_name']+out_col[2:-3]+['schedule_label']).sum().reset_index().sort_values(by=['first_views_pred_decay']))
# Out:
# INFO:root:Saved to hbo-outbound-datascience-content-dev/psi_first_views/psi_monthly_xgb_forecast.csv
#            first_view_month premiere_date  season_number  tier  \
# title_name
# #BAMARush        2023-01-01    2023-01-19              0     3
# #BAMARush        2023-01-01    2023-01-19              0     3
#
#            content_category              category  prequel_count  \
# title_name
# #BAMARush            movies  Documentary Features            0.0
# #BAMARush            movies  Documentary Features            0.0
#
#            prequel_featured_count prequel_featured_count_s  prequel_count_s  \
# title_name
# #BAMARush                      NA                       NA             -1.0
# #BAMARush                      NA                       NA             -1.0
#
#            page_views_s page_views  tier_adjusted  first_views_pred_decay  \
# title_name
# #BAMARush            NA         NA              3               881.12928
# #BAMARush            NA         NA              3               881.12928
#
#            model_train_date schedule_label
# title_name
# #BAMARush        2022-07-13          alpha
# #BAMARush        2022-07-13           beta
#             title_name premiere_date  season_number  tier content_category  \
# 0    DCU Green Lantern    2024-06-20              1     0           series
# 4   Sisterhood of Dune    2024-12-05              1     0           series
# 1  House Of The Dragon    2022-08-21              1     0           series
# 2  House Of The Dragon    2022-08-21              1     0           series
# 3  House Of The Dragon    2024-06-02              2     0           series
# 5       The Last Of Us    2023-01-15              1     0           series
# 6       The Last Of Us    2023-01-15              1     0           series
#
#                 category  prequel_count prequel_featured_count  \
# 0  Scripted Drama Series           -1.0                     NA
# 4  Scripted Drama Series           -1.0                     NA
# 1  Scripted Drama Series           -1.0                     NA
# 2  Scripted Drama Series           -1.0                     NA
# 3  Scripted Drama Series           -1.0                     NA
# 5  Scripted Drama Series           -1.0                     NA
# 6  Scripted Drama Series           -1.0                     NA
#
#   prequel_featured_count_s  prequel_count_s page_views_s page_views  \
# 0                      Low              1.0         High         NA
# 4                      Med              1.0           NA         NA
# 1                     High              1.0         High         NA
# 2                     High              1.0         High         NA
# 3                     High              2.0         High         NA
# 5                     High              1.0         High         NA
# 6                     High              1.0         High         NA
#
#    tier_adjusted schedule_label  first_views_pred_decay
# 0              0          alpha            285106.84375
# 4              0          alpha            505078.56250
# 1              0          alpha            565711.25000
# 2              0           beta            565711.25000
# 3              0          alpha            565711.25000
# 5              0          alpha            565711.25000
# 6              0           beta            565711.25000
#                                       title_name premiere_date  season_number  \
# 20                                The Gilded Age    2023-04-17              2
# 31  Winning Time: The Rise Of The Lakers Dynasty    2023-07-16              2
# 21                                The Gilded Age    2023-05-01              2
# 30  Winning Time: The Rise Of The Lakers Dynasty    2023-07-16              2
# 26                The Sex Lives of College Girls    2024-11-14              4
# 25                The Sex Lives of College Girls    2023-11-16              3
# 23                The Sex Lives of College Girls    2022-11-17              2
# 24                The Sex Lives of College Girls    2022-11-17              2
# 10                                  Love & Death    2022-10-20              1
# 11                                  Love & Death    2023-01-26              1
# 14                                       Penguin    2024-02-08              1
# 5                            Dead Boy Detectives    2024-05-02              2
# 16             Pretty Little Liars: Original Sin    2023-10-26              2
# 22                                The Gilded Age    2024-09-08              3
# 3                             Dead Boy Detective    2024-06-15              2
# 13                    Peacemaker / Amanda Waller    2024-08-01              2
# 17          Pretty Little Liars: Original Sin S2    2023-10-26              2
# 4                            Dead Boy Detectives    2023-05-11              1
# 12                               Love & Death S1    2023-01-26              1
# 6                         Dead Boy Detectives S1    2023-05-11              1
# 2                          And Just Like That S2    2023-06-08              2
# 27             The Sex Lives of College Girls S3    2023-11-16              3
# 7                                       Euphoria    2024-01-14              3
# 9                                    Gossip Girl    2022-12-01              2
# 8                                    Gossip Girl    2022-11-10              2
# 15             Pretty Little Liars: Original Sin    2022-07-28              1
# 18                                    Succession    2023-03-26              4
# 19                                    Succession    2023-03-26              4
# 28                                True Detective    2023-11-12              4
# 29                                True Detective    2023-11-12              4
# 1                             And Just Like That    2024-10-03              3
# 0                             And Just Like That    2023-06-08              2
#
#     tier content_category                category  prequel_count  \
# 20     1           series   Scripted Drama Series           -1.0
# 31     1           series   Scripted Drama Series           -1.0
# 21     1           series   Scripted Drama Series           -1.0
# 30     1           series   Scripted Drama Series           -1.0
# 26     1           series  Scripted Comedy Series           -1.0
# 25     1           series  Scripted Comedy Series           -1.0
# 23     1           series  Scripted Comedy Series           -1.0
# 24     1           series  Scripted Comedy Series           -1.0
# 10     1           series   Scripted Drama Series           -1.0
# 11     1           series   Scripted Drama Series           -1.0
# 14     1           series   Scripted Drama Series           -1.0
# 5      1           series   Scripted Drama Series           -1.0
# 16     1           series   Scripted Drama Series           -1.0
# 22     1           series   Scripted Drama Series           -1.0
# 3      1           series   Scripted Drama Series           -1.0
# 13     1           series   Scripted Drama Series           -1.0
# 17     1           series   Scripted Drama Series           -1.0
# 4      1           series   Scripted Drama Series           -1.0
# 12     1           series   Scripted Drama Series           -1.0
# 6      1           series   Scripted Drama Series           -1.0
# 2      1           series  Scripted Comedy Series           -1.0
# 27     1           series  Scripted Comedy Series           -1.0
# 7      1           series   Scripted Drama Series           -1.0
# 9      1           series   Scripted Drama Series           -1.0
# 8      1           series   Scripted Drama Series           -1.0
# 15     1           series   Scripted Drama Series           -1.0
# 18     1           series   Scripted Drama Series           -1.0
# 19     1           series   Scripted Drama Series           -1.0
# 28     1           series   Scripted Drama Series           -1.0
# 29     1           series   Scripted Drama Series           -1.0
# 1      1           series  Scripted Comedy Series           -1.0
# 0      1           series  Scripted Comedy Series           -1.0
#
#    prequel_featured_count prequel_featured_count_s  prequel_count_s  \
# 20                     NA                      Low              1.0
# 31                     NA                      Low              1.0
# 21                     NA                      Low              1.0
# 30                     NA                      Low              1.0
# 26                     NA                       NA              0.0
# 25                     NA                       NA              0.0
# 23                     NA                       NA              0.0
# 24                     NA                       NA              0.0
# 10                     NA                       NA              0.0
# 11                     NA                       NA              0.0
# 14                     NA                       NA              0.0
# 5                      NA                       NA              0.0
# 16                     NA                       NA              0.0
# 22                     NA                       NA              0.0
# 3                      NA                       NA              0.0
# 13                     NA                       NA              0.0
# 17                     NA                       NA              0.0
# 4                      NA                       NA              0.0
# 12                     NA                       NA              0.0
# 6                      NA                       NA              0.0
# 2                      NA                       NA              0.0
# 27                     NA                       NA              0.0
# 7                      NA                      Med              2.0
# 9                      NA                     High              2.0
# 8                      NA                     High              2.0
# 15                     NA                     High              2.0
# 18                     NA                      Med              3.0
# 19                     NA                      Med              3.0
# 28                     NA                     High              3.0
# 29                     NA                     High              3.0
# 1                      NA                     High              5.0
# 0                      NA                     High              4.0
#
#    page_views_s page_views  tier_adjusted schedule_label  \
# 20          Low         NA              1          alpha
# 31         High         NA              1           beta
# 21          Low         NA              1           beta
# 30         High         NA              1          alpha
# 26         High         NA              1          alpha
# 25         High         NA              1          alpha
# 23         High         NA              1          alpha
# 24         High         NA              1           beta
# 10         High         NA              1           beta
# 11         High         NA              1          alpha
# 14         High         NA              1          alpha
# 5            NA         NA              1          alpha
# 16           NA         NA              1          alpha
# 22           NA         NA              1          alpha
# 3            NA         NA              1          alpha
# 13           NA         NA              1          alpha
# 17           NA         NA              1           beta
# 4            NA         NA              1          alpha
# 12           NA         NA              1           beta
# 6            NA         NA              1           beta
# 2            NA         NA              1           beta
# 27           NA         NA              1           beta
# 7          High         NA              1          alpha
# 9          High         NA              1          alpha
# 8          High         NA              1           beta
# 15         High         NA              1          alpha
# 18         High         NA              1          alpha
# 19         High         NA              1           beta
# 28         High         NA              1          alpha
# 29         High         NA              1           beta
# 1          High         NA              1          alpha
# 0          High         NA              1          alpha
#
#     first_views_pred_decay
# 20            66267.554687
# 31            66267.554688
# 21            66267.554688
# 30            66267.554688
# 26            82684.562500
# 25            82684.562500
# 23            82684.562500
# 24            82684.562500
# 10            97308.484375
# 11            97308.484375
# 14            97308.484375
# 5            109223.078125
# 16           109223.078125
# 22           109223.078125
# 3            109223.078125
# 13           109223.078125
# 17           109223.078125
# 4            109223.078125
# 12           109223.078125
# 6            109223.078125
# 2            111901.445313
# 27           111901.445313
# 7            117395.695312
# 9            131488.609375
# 8            131488.609375
# 15           131488.609375
# 18           240301.906250
# 19           240301.906250
# 28           269149.218750
# 29           269149.218750
# 1            413545.875000
# 0            413545.875000
#                       title_name premiere_date  season_number  tier  \
# 31                     The Meg 2    2023-09-18              0     1
# 0    A Christmas Story Christmas    2022-11-17              0     1
# 1    A Christmas Story Christmas    2022-11-17              0     1
# 24      Shazam! Fury Of The Gods    2023-02-04              0     1
# 23      Shazam! Fury Of The Gods    2023-02-04              0     1
# 16       DC League Of Super-Pets    2022-09-12              0     1
# 15       DC League Of Super-Pets    2022-09-12              0     1
# 7                   Batgirl (DC)    2023-08-17              0     1
# 8                   Batgirl (DC)    2023-08-17              0     1
# 19                         Elvis    2022-08-08              0     1
# 11                  Black Canary    2024-03-15              0     1
# 17           Don't Worry Darling    2022-11-07              0     1
# 28                     The Flash    2023-08-07              0     1
# 10                    Black Adam    2022-12-05              0     1
# 9                     Black Adam    2022-12-05              0     1
# 6                         Barbie    2023-09-04              0     1
# 29                     The Flash    2023-08-07              0     1
# 20                       Furiosa    2024-07-08              0     1
# 32                     The Nun 2    2023-10-23              0     1
# 36     Untitled Holiday Movie #2    2023-11-30              0     1
# 22                   Salem's Lot    2022-10-24              0     1
# 13                   Blue Beetle    2023-10-02              0     1
# 34        Untitled DC Event Film    2024-11-18              0     1
# 12                   Blue Beetle    2023-10-02              0     1
# 33        Untitled DC Event Film    2024-08-05              0     1
# 35     Untitled Holiday Movie #1    2023-11-23              0     1
# 27                 The Back Nine    2023-11-02              0     1
# 37     Untitled Holiday Movie #3    2023-12-07              0     1
# 25                  Static Shock    2024-03-15              0     1
# 21      One Night in Gotham City    2024-03-15              0     1
# 14                Coyote vs Acme    2023-11-23              0     1
# 5                       Avatar 2    2023-02-14              0     1
# 4                       Avatar 2    2023-02-14              0     1
# 26                 The Back Nine    2023-11-02              0     1
# 18                Dune: Part Two    2023-12-04              0     1
# 3   Aquaman and the Lost Kingdom    2023-05-15              0     1
# 2   Aquaman and the Lost Kingdom    2023-05-15              0     1
# 30               The Flintstones    2024-11-07              0     1
#
#    content_category              category  prequel_count  \
# 31           movies  Pay 1 WB Theatricals            2.0
# 0            movies     Scripted Features            0.0
# 1            movies     Scripted Features            0.0
# 24           movies  Pay 1 WB Theatricals            1.0
# 23           movies  Pay 1 WB Theatricals            1.0
# 16           movies  Pay 1 WB Theatricals            0.0
# 15           movies  Pay 1 WB Theatricals            0.0
# 7            movies     Scripted Features            0.0
# 8            movies     Scripted Features            0.0
# 19           movies  Pay 1 WB Theatricals            0.0
# 11           movies     Scripted Features            0.0
# 17           movies  Pay 1 WB Theatricals            0.0
# 28           movies  Pay 1 WB Theatricals            2.0
# 10           movies  Pay 1 WB Theatricals            1.0
# 9            movies  Pay 1 WB Theatricals            1.0
# 6            movies  Pay 1 WB Theatricals            0.0
# 29           movies  Pay 1 WB Theatricals            2.0
# 20           movies  Pay 1 WB Theatricals            0.0
# 32           movies  Pay 1 WB Theatricals            0.0
# 36           movies     Scripted Features            0.0
# 22           movies  Pay 1 WB Theatricals            0.0
# 13           movies  Pay 1 WB Theatricals            0.0
# 34           movies  Pay 1 WB Theatricals            0.0
# 12           movies  Pay 1 WB Theatricals            0.0
# 33           movies  Pay 1 WB Theatricals            0.0
# 35           movies     Scripted Features            0.0
# 27           movies     Scripted Features            0.0
# 37           movies     Scripted Features            0.0
# 25           movies     Scripted Features            0.0
# 21           movies     Scripted Features            0.0
# 14           movies     Scripted Features            0.0
# 5            movies                  Pay1            0.0
# 4            movies                  Pay1            0.0
# 26           movies     Scripted Features            0.0
# 18           movies  Pay 1 WB Theatricals            2.0
# 3            movies  Pay 1 WB Theatricals            1.0
# 2            movies  Pay 1 WB Theatricals            1.0
# 30           movies     Scripted Features            3.0
#
#    prequel_featured_count prequel_featured_count_s  prequel_count_s  \
# 31                    Med                       NA             -1.0
# 0                      NA                       NA             -1.0
# 1                      NA                       NA             -1.0
# 24                    Med                       NA             -1.0
# 23                    Med                       NA             -1.0
# 16                     NA                       NA             -1.0
# 15                     NA                       NA             -1.0
# 7                      NA                       NA             -1.0
# 8                      NA                       NA             -1.0
# 19                     NA                       NA             -1.0
# 11                     NA                       NA             -1.0
# 17                     NA                       NA             -1.0
# 28                    Med                       NA             -1.0
# 10                    Med                       NA             -1.0
# 9                     Med                       NA             -1.0
# 6                      NA                       NA             -1.0
# 29                    Med                       NA             -1.0
# 20                     NA                       NA             -1.0
# 32                     NA                       NA             -1.0
# 36                     NA                       NA             -1.0
# 22                     NA                       NA             -1.0
# 13                     NA                       NA             -1.0
# 34                     NA                       NA             -1.0
# 12                     NA                       NA             -1.0
# 33                     NA                       NA             -1.0
# 35                     NA                       NA             -1.0
# 27                     NA                       NA             -1.0
# 37                     NA                       NA             -1.0
# 25                     NA                       NA             -1.0
# 21                     NA                       NA             -1.0
# 14                     NA                       NA             -1.0
# 5                      NA                       NA             -1.0
# 4                      NA                       NA             -1.0
# 26                     NA                       NA             -1.0
# 18                   High                       NA             -1.0
# 3                    High                       NA             -1.0
# 2                    High                       NA             -1.0
# 30                   High                       NA             -1.0
#
#    page_views_s page_views  tier_adjusted schedule_label  \
# 31           NA       High              1           beta
# 0            NA       High              1          alpha
# 1            NA       High              1           beta
# 24           NA       High              1           beta
# 23           NA       High              1          alpha
# 16           NA       High              1           beta
# 15           NA       High              1          alpha
# 7            NA       High              1          alpha
# 8            NA       High              1           beta
# 19           NA       High              1           beta
# 11           NA       High              1          alpha
# 17           NA       High              1           beta
# 28           NA       High              1          alpha
# 10           NA       High              1           beta
# 9            NA       High              1          alpha
# 6            NA       High              1           beta
# 29           NA       High              1           beta
# 20           NA       High              1          alpha
# 32           NA         NA              1           beta
# 36           NA         NA              1           beta
# 22           NA         NA              1           beta
# 13           NA         NA              1           beta
# 34           NA         NA              1          alpha
# 12           NA         NA              1          alpha
# 33           NA         NA              1          alpha
# 35           NA         NA              1           beta
# 27           NA         NA              1           beta
# 37           NA         NA              1           beta
# 25           NA         NA              1          alpha
# 21           NA         NA              1          alpha
# 14           NA         NA              1          alpha
# 5            NA         NA              1           beta
# 4            NA         NA              1          alpha
# 26           NA         NA              1          alpha
# 18           NA       High              1           beta
# 3            NA       High              1           beta
# 2            NA       High              1          alpha
# 30           NA         NA              1          alpha
#
#     first_views_pred_decay
# 31           116432.921875
# 0            116432.921875
# 1            116432.921875
# 24           116432.921875
# 23           116432.921875
# 16           116432.921875
# 15           116432.921875
# 7            116432.921875
# 8            116432.921875
# 19           116432.921875
# 11           116432.921875
# 17           116432.921875
# 28           116432.921875
# 10           116432.921875
# 9            116432.921875
# 6            116432.921875
# 29           116432.921875
# 20           116432.921875
# 32           177607.921875
# 36           177607.921875
# 22           177607.921875
# 13           177607.921875
# 34           177607.921875
# 12           177607.921875
# 33           177607.921875
# 35           177607.921875
# 27           177607.921875
# 37           177607.921875
# 25           177607.921875
# 21           177607.921875
# 14           177607.921875
# 5            177607.921875
# 4            177607.921875
# 26           177607.921875
# 18           282055.218750
# 3            282055.218750
# 2            282055.218750
# 30           337670.875000

# %% [markdown]
# ## Feature importance

# %%
import shap
def get_shap(df_pred, model, ohe, features, value=0):
    """
    ev, shap, x_ohe = get_shap(df_pred, 'pop', model_path, 'return')
    shap.force_plot(ev, shap, x_ohe)
    """
    df_x = df_pred[features]

    shap.initjs()
    x_ohe = ohe.transform(df_x)
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(x_ohe)
    
    shap.summary_plot(shap_values, x_ohe)
    shap.summary_plot(shap_values, x_ohe, plot_type="bar")
    return explainer.expected_value, shap_values[value,:], x_ohe.iloc[value,:]

# dict_model = Utils.read_pkl_s3(input_bucket, key_path, f'fv_{date_train}.pkl')
# model = dict_model['model']
# ohe = dict_model['ohe']
# features_cat=['tier_adj','category','content_category', 'page_views','page_views_s','prequel_featured_count','prequel_featured_count_s',] 
# features_cont= ['prequel_count','prequel_count_s',] 
# df_test = df_in_pred.copy()


ev, shap_values, x_ohe = get_shap(df_test[(df_test.tier_adj=='Gold') & (df_test.category=='Scripted Drama Series')], model, ohe, features_cat + features_cont)
# ev, shap_values, x_ohe = get_shap(df_test, model, ohe, features_cat + features_cont)
# ev, shap_values, x_ohe = get_shap(df_test[df_test.title_name.str.contains('Dragon')], model, ohe, features_cat + features_cont)

shap.force_plot(ev, shap_values, x_ohe)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iEBLM77TC9J1N1Q51MZ8O'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 9.628619194030762, "outValue": 10.201852798461914, "link": "identity", "featureNames": ["tier_adj_Silver", "tier_adj_Bronze", "tier_adj_Gold", "tier_adj_Platinum", "category_Docu-Series", "category_Unscripted Series", "category_Documentary Features", "category_Specials", "category_International", "category_Scripted Features", "category_Scripted Comedy Series", "category_Pay1", "category_Kids & Family", "category_Scripted Drama Series", "category_Popcorn", "content_category_series", "content_category_movies", "content_category_special", "page_views_NA", "page_views_High", "page_views_Low", "page_views_s_NA", "page_views_s_High", "page_views_s_Low", "prequel_featured_count_NA", "prequel_featured_count_Low", "prequel_featured_count_High", "prequel_featured_count_Med", "prequel_featured_count_s_NA", "prequel_featured_count_s_Low", "prequel_featured_count_s_High", "prequel_featured_count_s_Med", "prequel_count", "prequel_count_s"], "features": {"0": {"effect": 0.7805549502372742, "value": 0.0}, "1": {"effect": 0.7938448786735535, "value": 0.0}, "2": {"effect": -0.6144437193870544, "value": 1.0}, "4": {"effect": 0.004160001408308744, "value": 0.0}, "5": {"effect": -0.0030987607315182686, "value": 0.0}, "6": {"effect": -0.005326041951775551, "value": 0.0}, "7": {"effect": -0.005924233701080084, "value": 0.0}, "8": {"effect": 0.036087267100811005, "value": 0.0}, "9": {"effect": -0.010040009394288063, "value": 0.0}, "10": {"effect": -0.00456665176898241, "value": 0.0}, "11": {"effect": 0.005368731915950775, "value": 0.0}, "12": {"effect": 0.05507727339863777, "value": 0.0}, "13": {"effect": -0.04155975207686424, "value": 1.0}, "14": {"effect": -0.06518609821796417, "value": 0.0}, "15": {"effect": -0.11275142431259155, "value": 1.0}, "16": {"effect": -0.00012937351129949093, "value": 0.0}, "17": {"effect": 0.011124907992780209, "value": 0.0}, "18": {"effect": -0.007082212716341019, "value": 1.0}, "19": {"effect": -0.007790722418576479, "value": 0.0}, "21": {"effect": 0.013787277974188328, "value": 0.0}, "22": {"effect": -0.07526927441358566, "value": 1.0}, "24": {"effect": -0.005454393569380045, "value": 1.0}, "26": {"effect": -0.008139949291944504, "value": 0.0}, "27": {"effect": 0.007784171495586634, "value": 0.0}, "28": {"effect": -0.08865472674369812, "value": 1.0}, "29": {"effect": -0.04805571213364601, "value": 0.0}, "31": {"effect": -0.007075977977365255, "value": 0.0}, "32": {"effect": 0.016722258180379868, "value": -1.0}, "33": {"effect": -0.040728986263275146, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iEBLM77TC9J1N1Q51MZ8O')
#   );
# </script>

# %%
ev, shap_values, x_ohe = get_shap(df_test[(df_test.tier_adj=='Gold') & (df_test.category=='Scripted Comedy Series')], model, ohe, features_cat + features_cont)
# ev, shap_values, x_ohe = get_shap(df_test, model, ohe, features_cat + features_cont)
# ev, shap_values, x_ohe = get_shap(df_test[df_test.title_name.str.contains('Dragon')], model, ohe, features_cat + features_cont)

shap.force_plot(ev, shap_values, x_ohe)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iV57GS0I2OP62PAU3P7UY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 9.628619194030762, "outValue": 11.392106056213379, "link": "identity", "featureNames": ["tier_adj_Silver", "tier_adj_Bronze", "tier_adj_Gold", "tier_adj_Platinum", "category_Docu-Series", "category_Unscripted Series", "category_Documentary Features", "category_Specials", "category_International", "category_Scripted Features", "category_Scripted Comedy Series", "category_Pay1", "category_Kids & Family", "category_Scripted Drama Series", "category_Popcorn", "content_category_series", "content_category_movies", "content_category_special", "page_views_NA", "page_views_High", "page_views_Low", "page_views_s_NA", "page_views_s_High", "page_views_s_Low", "prequel_featured_count_NA", "prequel_featured_count_Low", "prequel_featured_count_High", "prequel_featured_count_Med", "prequel_featured_count_s_NA", "prequel_featured_count_s_Low", "prequel_featured_count_s_High", "prequel_featured_count_s_Med", "prequel_count", "prequel_count_s"], "features": {"0": {"effect": 1.0533438920974731, "value": 0.0}, "1": {"effect": 0.8601817488670349, "value": 0.0}, "2": {"effect": -0.45714229345321655, "value": 1.0}, "4": {"effect": 0.004930381663143635, "value": 0.0}, "5": {"effect": -0.005087736062705517, "value": 0.0}, "6": {"effect": 0.0036379192024469376, "value": 0.0}, "7": {"effect": -0.0032014395110309124, "value": 0.0}, "8": {"effect": 0.03608034551143646, "value": 0.0}, "9": {"effect": -0.010335490107536316, "value": 0.0}, "10": {"effect": 0.0903751403093338, "value": 1.0}, "11": {"effect": 0.009848587214946747, "value": 0.0}, "12": {"effect": 0.05507727339863777, "value": 0.0}, "13": {"effect": 0.006863897666335106, "value": 0.0}, "14": {"effect": -0.05964842438697815, "value": 0.0}, "15": {"effect": -0.036103807389736176, "value": 1.0}, "16": {"effect": -0.00012937351129949093, "value": 0.0}, "17": {"effect": 0.011124907992780209, "value": 0.0}, "18": {"effect": -0.009922006167471409, "value": 1.0}, "19": {"effect": -0.00950607843697071, "value": 0.0}, "21": {"effect": 0.07660409063100815, "value": 0.0}, "22": {"effect": -0.06593163311481476, "value": 1.0}, "24": {"effect": -0.005841003730893135, "value": 1.0}, "26": {"effect": -0.008139949291944504, "value": 0.0}, "27": {"effect": 0.007784171495586634, "value": 0.0}, "28": {"effect": 0.07425865530967712, "value": 0.0}, "29": {"effect": 0.16714167594909668, "value": 1.0}, "31": {"effect": -0.0029958714731037617, "value": 0.0}, "32": {"effect": 0.02537725120782852, "value": -1.0}, "33": {"effect": -0.04515829309821129, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iV57GS0I2OP62PAU3P7UY')
#   );
# </script>

# %% [markdown]
# ## Check model drift

# %%
# import boto3

# s3 = boto3.resource('s3')
# my_bucket = s3.Bucket(input_bucket)

# ## Get all .pkl files in s3 bucket to find the previously trained model 
# pkl_list=[]
# for my_bucket_object in my_bucket.objects.filter(Prefix=key_path):
#     if my_bucket_object.key.endswith('.pkl') and my_bucket_object.key.startswith(f'{key_path}/fv'):
#         pkl_list.append(my_bucket_object.key)
# base_model_date = pkl_list[-2][-14:-4]


# ## Predict on the current df_pred using the previous model 
# logger.info(f'CHECKING MODEL DRIFT FOR {date_pred} vs. {base_model_date}')

# date_pred_base = base_model_date
# df_out_pred_base = XGB(df_in_pred, mode, date_pred_base).return_df()

# df_out_drift = df_out_pred.merge(df_out_pred_base, on=['title_name','content_category','category','season_number'], suffixes=['','_base'], how='left')
# df_out_drift['effective_start_month'] = pd.to_datetime(df_out_drift['effective_start_date']).dt.to_period('M').dt.to_timestamp()
# df_out_drift['pred_diff'] = df_out_drift['first_views_pred'] - df_out_drift['first_views_pred_base']
# df_out_drift['pred_diff_pct'] = df_out_drift['pred_diff']/df_out_drift['first_views_pred_base']

# ## Aggregate monthly drift 
# df_out_drift_mth = df_out_drift.groupby(by=['effective_start_month']).sum().reset_index()
# display(df_out_drift_mth[(df_out_drift_mth['effective_start_month']>=date_pred) & (df_out_drift_mth['effective_start_month']<='2023-01-01')][['effective_start_month','first_views_pred','first_views_pred_base','pred_diff']])
# logger.info(f'Monthly MAE: {df_out_drift_mth.pred_diff.abs().mean()}')

# ## Title level drift 
# df_top = df_out_drift[(df_out_drift['tier']<=1)& (df_out_drift['effective_start_date']>=date_pred) & (df_out_drift['effective_start_date']<='2023-01-01')]
# display(df_top[['title_name','effective_start_date','tier','category','content_category','first_views_pred','first_views_pred_base','pred_diff','pred_diff_pct']].sort_values(by='effective_start_date'))
# logger.info(f'Title MAPE FOR Tier 0,1 : {df_top.pred_diff_pct.abs().mean()}')
# Out:
# INFO:root:CHECKING MODEL DRIFT FOR 2022-03-22 vs. 2022-02-09
# INFO:root:Read from hbo-ingest-datascience-content-dev/psi_first_views/fv_2022-03-22.pkl
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:318: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    effective_start_month  first_views_pred  first_views_pred_base  \
# 15            2022-04-01      854439.87500           920412.50000
# 16            2022-05-01      585988.06250           737540.68750
# 17            2022-06-01      352366.00000           342063.03125
# 18            2022-07-01      314223.09375           318921.21875
# 19            2022-08-01      816481.62500           794327.93750
# 20            2022-09-01      423722.62500           377030.37500
# 21            2022-10-01      711015.68750           689516.00000
# 22            2022-11-01      710006.06250           716378.31250
# 23            2022-12-01      510215.03125           497303.28125
# 24            2023-01-01      692935.00000           682806.25000
#
#         pred_diff
# 15  -65972.609375
# 16 -151552.625000
# 17   10302.951172
# 18   -4698.153320
# 19   22153.677734
# 20   46692.226562
# 21   21499.730469
# 22   -6372.216309
# 23   12911.759766
# 24   10128.729492
# INFO:root:Monthly MAE: 59873.01171875
#                                       title_name effective_start_date  tier  \
# 625                                   The Batman           2022-04-18     1
# 646                         The Flight Attendant           2022-04-21     0
# 717                                The Staircase           2022-05-05     1
# 167  Fantastic Beasts: The Secrets of Dumbledore           2022-05-30     1
# 169                          Father of the Bride           2022-06-16     1
# 797                                    Westworld           2022-06-26     1
# 512            Pretty Little Liars: Original Sin           2022-07-07     1
# 143                                        Elvis           2022-08-08     1
# 333                          House Of The Dragon           2022-08-21     0
# 119                      DC League Of Super-Pets           2022-09-12     1
# 421                                 Love & Death           2022-10-20     1
# 541                                  Salem's Lot           2022-10-24     1
# 430                      Magic Mike's Last Dance           2022-10-27     1
# 129                          Don't Worry Darling           2022-11-07     1
# 211                                  Gossip Girl           2022-11-10     1
# 711               The Sex Lives of College Girls           2022-11-17     1
# 19                   A Christmas Story Christmas           2022-11-17     1
# 73                                    Black Adam           2022-12-05     1
#
#                    category content_category  first_views_pred  \
# 625    Pay 1 WB Theatricals           movies     229216.109375
# 646   Scripted Drama Series           series     466477.093750
# 717   Scripted Drama Series           series     152018.984375
# 167    Pay 1 WB Theatricals           movies     213999.375000
# 169       Scripted Features           movies     159487.390625
# 797   Scripted Drama Series           series     152018.984375
# 512   Scripted Drama Series           series     152018.984375
# 143    Pay 1 WB Theatricals           movies     145503.671875
# 333   Scripted Drama Series           series     466477.093750
# 119    Pay 1 WB Theatricals           movies     145503.671875
# 421   Scripted Drama Series           series     152018.984375
# 541    Pay 1 WB Theatricals           movies     145503.671875
# 430       Scripted Features           movies     159487.390625
# 129    Pay 1 WB Theatricals           movies     145503.671875
# 211   Scripted Drama Series           series     152018.984375
# 711  Scripted Comedy Series           series      84807.781250
# 19        Scripted Features           movies     159487.390625
# 73     Pay 1 WB Theatricals           movies     229216.109375
#
#      first_views_pred_base      pred_diff  pred_diff_pct
# 625          248287.421875  -19071.312500      -0.076811
# 646          483773.718750  -17296.625000      -0.035754
# 717          150452.390625    1566.593750       0.010413
# 167          368620.156250 -154620.781250      -0.419458
# 169          141358.250000   18129.140625       0.128250
# 797          150452.390625    1566.593750       0.010413
# 512          150452.390625    1566.593750       0.010413
# 143          113163.937500   32339.734375       0.285778
# 333          483773.718750  -17296.625000      -0.035754
# 119          113163.937500   32339.734375       0.285778
# 421          150452.390625    1566.593750       0.010413
# 541          113163.937500   32339.734375       0.285778
# 430          141358.250000   18129.140625       0.128250
# 129          113163.937500   32339.734375       0.285778
# 211          150452.390625    1566.593750       0.010413
# 711          132148.218750  -47340.437500      -0.358237
# 19           141358.250000   18129.140625       0.128250
# 73           248287.421875  -19071.312500      -0.076811
# INFO:root:Title MAPE FOR Tier 0,1 : 0.14348602294921875

# %% [markdown]
# ## Check shift in prediction

# %%
# def get_tier_cat(df_pred_future_fv):
#     ### Get tier_cat 
#     f_pay = (df_pred_future_fv['category']=='Pay1')
#     f_payt = (df_pred_future_fv['category']=='Pay 1 WB Theatricals')
#     f_popcorn = (df_pred_future_fv['category']=='Popcorn')
#     f_t0 = (df_pred_future_fv['tier']==0) & ~(df_pred_future_fv['category'].isin(['Pay1','Popcorn','Pay 1 WB Theatricals']))
#     f_t1 = (df_pred_future_fv['tier']==1) & ~(df_pred_future_fv['category'].isin(['Pay1','Popcorn','Pay 1 WB Theatricals']))
#     f_t2 = (df_pred_future_fv['tier']==2) & ~(df_pred_future_fv['category'].isin(['Pay1','Popcorn','Pay 1 WB Theatricals']))
#     f_t3 = (df_pred_future_fv['tier']==3) & ~(df_pred_future_fv['category'].isin(['Pay1','Popcorn','Pay 1 WB Theatricals']))

#     df_pred_future_fv['tier_cat'] = None
#     # df_pred_future_fv.loc[f_payt, 'tier_cat'] = 'Pay1 Theatrical'
#     df_pred_future_fv.loc[f_pay, 'tier_cat'] = 'Pay 1'
#     df_pred_future_fv.loc[f_payt, 'tier_cat'] = 'Pay 1 WB Theatricals'
#     df_pred_future_fv.loc[f_popcorn, 'tier_cat'] = 'Popcorn'
#     df_pred_future_fv.loc[f_t0, 'tier_cat'] = 'Tier 1+'
#     df_pred_future_fv.loc[f_t1, 'tier_cat'] = 'Tier 1'
#     df_pred_future_fv.loc[f_t2, 'tier_cat'] = 'Tier 2'
#     df_pred_future_fv.loc[f_t3, 'tier_cat'] = 'Tier 3'
#     return df_pred_future_fv

# import plotly as py
# import plotly.graph_objects as go

# def get_stacked_plot(df_plt, var, title):
#     fig = go.Figure()
#     tier_cat_list = ['Pay 1', 'Tier 3','Tier 2','Tier 1','Tier 1+','Popcorn','Pay 1 WB Theatricals',]  ## px.colors.sequential.Plotly3

#     for r, c in zip(tier_cat_list,  ['#0508b8','#3c19f0','#6b1cfb','#bf1cfd','#f246fe','#fe88fc','#fec3fe']):
#         plot_df = df_plt[df_plt.tier_cat == r]
#         fig.add_trace(
#             go.Bar(x=plot_df.first_view_quarter, y=plot_df[var], name=r, marker_color=c, 
#                    text=plot_df[var], textposition='inside', textangle=0) ,
#         )

#     annotation=[]    
#     quarters=df_plt.first_view_quarter.unique().tolist()
#     for q in quarters:#, m in itertools.product(quarters, models):
#         plot_df = df_plt[(df_plt.first_view_quarter==q)]    
#         dic= {"x":q, "y": plot_df[var].sum()*1.05,
#                      "text": f'{plot_df[var].sum()/1000000:.2f} M', 
#                      "showarrow": False} 
#         annotation.append(dic)


#     fig.update_layout(
#         template="simple_white",
#         title=title,
#         xaxis=dict(title_text="first_view_quarter"),
#         yaxis=dict(title_text="first_views"),
#         barmode="stack",
#         width=900,
#         height=400,
#         uniformtext_minsize=8, 
#         uniformtext_mode='hide',
#         annotations=annotation
#     )
#     py.offline.init_notebook_mode(connected=True) 
#     py.offline.iplot(fig)
#     return 


# logger.info(f'CHECKING PREDICTION DIFF FOR {date_pred} vs. {base_model_date}')
# out_col = ['title_name', 'first_view_month','first_view_quarter', 'effective_start_date', 'season_number',
#            'tier','content_category', 'category', 'prequel_count', 'prequel_featured_count','pred_date',
#            'tier_adj', 'first_views_pred']

# ## new model 
# df_pred_decay['pred_date'] = pd.to_datetime(df_pred_decay['pred_date']).dt.strftime('%Y-%m-%d')
# df_pred_decay_month = df_pred_decay.groupby(by=out_col[:-2]).sum().reset_index()
# df_pred_decay_month['first_view_month']=pd.to_datetime(df_pred_decay_month['first_view_month'])
# df_pred_decay_month['tier'] = df_pred_decay_month['tier'].astype(int)
# df_pred_decay_month = get_tier_cat(df_pred_decay_month)
# df_pred_decay_q =  df_pred_decay_month.groupby(by=['first_view_quarter','pred_date','tier_cat']).sum().reset_index()

# ## base model 
# df_pred_decay_base = Utils.read_csv_s3(input_bucket, key_path, f'psi_daily_xgb_forecast_{base_model_date}.csv')
# df_pred_decay_base['pred_date'] = pd.to_datetime(df_pred_decay_base['pred_date']).dt.strftime('%Y-%m-%d')
# df_pred_decay_month_base =  df_pred_decay_base.groupby(by=out_col[:-2]).sum().reset_index()
# df_pred_decay_month_base['first_view_month']=pd.to_datetime(df_pred_decay_month_base['first_view_month'])
# df_pred_decay_month_base['first_view_quarter'] = pd.to_datetime(df_pred_decay_month_base['first_view_month']).dt.to_period('Q').dt.to_timestamp()
# df_pred_decay_month_base['effective_start_date']=pd.to_datetime(df_pred_decay_month_base['effective_start_date'])
# df_pred_decay_month_base = get_tier_cat(df_pred_decay_month_base)
# df_pred_decay_q_base =  df_pred_decay_month_base.groupby(by=['first_view_quarter','pred_date','tier_cat']).sum().reset_index()


# # ## Quarter level difference 
# grpby_quarter= ['first_view_quarter','pred_date','tier_cat']
# df_pred_q = pd.concat([df_pred_decay_q, df_pred_decay_q_base])
# df_pred_q = df_pred_q.groupby(by=grpby_quarter)[['first_views_pred_decay']].sum().reset_index()

# df_pred_q['first_views'] = df_pred_q['first_views_pred_decay']


# ## Plot 
# df_plt = df_pred_q.round()
# df_plt['first_view_quarter']= pd.to_datetime(df_plt['first_view_quarter']).dt.to_period('Q')
# df_plt = df_plt[(df_plt['first_view_quarter']>'2021Q4') & (df_plt['first_view_quarter']<'2025Q1')]

# df_plt['first_view_quarter'] = df_plt['first_view_quarter'].astype('str')
# get_stacked_plot(df_plt[df_plt.pred_date==date_pred_base], 'first_views_pred_decay', date_pred_base)
# get_stacked_plot(df_plt[df_plt.pred_date==date_pred], 'first_views_pred_decay', date_pred)

# # ## Title level difference 
# df_pred_comp = df_pred_decay_month.merge(df_pred_decay_month_base, on=out_col[:-3], suffixes=['','_base'], how='left')
# grpby=['title_name','effective_start_date','tier','category']
# df_pred_comp_title =  df_pred_comp[grpby+['first_views_pred_decay','first_views_pred_decay_base']].groupby(by=grpby).sum().reset_index()
# df_top = df_pred_comp_title[(df_pred_comp_title['tier']<=1)& (df_pred_comp_title['effective_start_date']>=date_pred) & (df_pred_comp_title['effective_start_date']<='2023-01-01')]
# df_top['diff_pct'] = (df_top['first_views_pred_decay']-df_top['first_views_pred_decay_base'])/df_top['first_views_pred_decay_base']
# display(df_top.sort_values(by='effective_start_date'))
# Out:
# INFO:root:CHECKING PREDICTION DIFF FOR 2022-03-22 vs. 2022-02-09
# INFO:root:Read from hbo-ingest-datascience-content-dev/psi_first_views/psi_daily_xgb_forecast_2022-02-09.csv
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:110: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       title_name effective_start_date  tier  \
# 621                                   The Batman           2022-04-18     1
# 642                         The Flight Attendant           2022-04-21     0
# 711                                The Staircase           2022-05-05     1
# 165  Fantastic Beasts: The Secrets of Dumbledore           2022-05-30     1
# 167                          Father of the Bride           2022-06-16     1
# 777                                    Westworld           2022-06-26     1
# 508            Pretty Little Liars: Original Sin           2022-07-07     1
# 141                                        Elvis           2022-08-08     1
# 331                          House Of The Dragon           2022-08-21     0
# 117                      DC League Of Super-Pets           2022-09-12     1
# 417                                 Love & Death           2022-10-20     1
# 537                                  Salem's Lot           2022-10-24     1
# 426                      Magic Mike's Last Dance           2022-10-27     1
# 127                          Don't Worry Darling           2022-11-07     1
# 209                                  Gossip Girl           2022-11-10     1
# 705               The Sex Lives of College Girls           2022-11-17     1
# 17                   A Christmas Story Christmas           2022-11-17     1
# 71                                    Black Adam           2022-12-05     1
#
#                    category  first_views_pred_decay  \
# 621    Pay 1 WB Theatricals           229216.109375
# 642   Scripted Drama Series           466477.093750
# 711   Scripted Drama Series           152018.984375
# 165    Pay 1 WB Theatricals           213999.375000
# 167       Scripted Features           159487.390625
# 777   Scripted Drama Series           152018.984375
# 508   Scripted Drama Series           152018.984375
# 141    Pay 1 WB Theatricals           145503.671875
# 331   Scripted Drama Series           466477.093750
# 117    Pay 1 WB Theatricals           145503.671875
# 417   Scripted Drama Series           152018.984375
# 537    Pay 1 WB Theatricals           145503.671875
# 426       Scripted Features           159487.390625
# 127    Pay 1 WB Theatricals           145503.671875
# 209   Scripted Drama Series           152018.984375
# 705  Scripted Comedy Series            84807.781250
# 17        Scripted Features           159487.390625
# 71     Pay 1 WB Theatricals           229216.109375
#
#      first_views_pred_decay_base  diff_pct
# 621                     0.000000       inf
# 642                456063.312500  0.022834
# 711                119941.039062  0.267448
# 165                323731.187500 -0.338960
# 167                     0.000000       inf
# 777                119941.039062  0.267448
# 508                     0.000000       inf
# 141                133187.968750  0.092469
# 331                456063.312500  0.022834
# 117                     0.000000       inf
# 417                119941.039063  0.267448
# 537                133187.968750  0.092469
# 426                     0.000000       inf
# 127                133187.968750  0.092469
# 209                119941.039062  0.267448
# 705                 65324.093750  0.298262
# 17                      0.000000       inf
# 71                      0.000000       inf

# %%
# import plotly.graph_objects as go
# import itertools 

# df_plt = df_pred_q.round()
# df_plt = df_plt[(df_plt['first_view_quarter']>'2021Q4') & (df_plt['first_view_quarter']<'2025Q1')]
# df_plt['first_view_quarter'] = df_plt['first_view_quarter'].astype(str)
# df_plt['model_name'] = 'new'
# df_plt.loc[df_plt['pred_date']==base_model_date, 'model_name']='old'

# fig = go.Figure()
# tier_cat_list = ['Pay 1', 'Tier 3','Tier 2','Tier 1','Tier 1+','Popcorn','Pay 1 WB Theatricals',]  ## px.colors.sequential.Plotly3

# for r, c in zip(tier_cat_list,  ['#0508b8','#3c19f0','#6b1cfb','#bf1cfd','#f246fe','#fe88fc','#fec3fe']):
#     plot_df = df_plt[df_plt.tier_cat == r]
#     fig.add_trace(
#         go.Bar(x=[plot_df.first_view_quarter, plot_df.model_name], y=plot_df.first_views, name=r, marker_color=c, 
#                text=plot_df.first_views, textposition='inside', textangle=0) ,
#     )

# annotation=[]    
# quarters=df_plt.first_view_quarter.unique().tolist()
# models = ['old','new']
# # models = [date_pred, date_pred_base]
# for q, m in itertools.product(quarters, models):
#     plot_df = df_plt[(df_plt.first_view_quarter==q) & (df_plt.model_name==m)]    
#     dic= {"x":[q, m], "y": plot_df.first_views.sum()*1.05,
#                  "text": f'{plot_df.first_views.sum()/1000000:.2f} M', 
#                  "showarrow": False} 
#     annotation.append(dic)

# fig.update_layout(
#     template="simple_white",
#     xaxis=dict(title_text="first_view_quarter"),
#     yaxis=dict(title_text="first_views"),
#     barmode="stack",
#     uniformtext_minsize=8, 
#     uniformtext_mode='hide',
#     annotations=annotation
# )

# fig
